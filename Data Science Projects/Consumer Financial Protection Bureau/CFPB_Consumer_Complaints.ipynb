# %% [markdown]
# # Project Introduction

# %% [markdown]
# This project analyzes customer complaints about various financial products and services. These are reported to the Consumer Financial Protection Bureau (CFPB). In every week, the Bureau collects thousands of submitted customer complaints and forwards them to the respective companies for response. Once a company responds, immediately or after 15 days, complaints are published publicly, providing a transparent view of customer experiences in the financial space. By examining the dataset, we gather insights into customer grievances, customer responsiveness and underlying patterns/trends in the quality of products in the financial sector.

# %% [markdown]
# ## Problem Context

# %% [markdown]
# Customers have challenges navigating the financial sector and their associated products. Many are met with barriers, such a lack of accepted IDs to open a new bank or fintech account. Others suffer from a lack of access to certain financial products due to geographical locations. Financial companies on the other hand provide a lack of clear communication relating to hidden fees, for example, with opening new accounts or credit cards. This makes customers lose trust in them, leading to unexpected situations and recurring problems and eventually frustration.
#
# Analyzing customer complaints allows companies to address recurring problems in a timely manner. It assists them in streamlining their service rendering process to best assist customer needs, allowing customers to benefit from the transparency and awareness associated with it.

# %% [markdown]
# ## Research Questions

# %% [markdown]
# 1. Which financial products generate the most consumer complaints?
# 2. What are the most common issues reported by consumers?
# 3. How responsive are companies in addressing complaints, and what is the distribution of response times?
# 4. Are there noticeable trends in complaints over time or by geographic location?
# 5. Which companies resolve complaints satisfactorily on a consistent basis, and which struggle?
# 6. Can patterns in the complaints provide insights into systemic issues in the financial sector?

# %% [markdown]
# ## Project Objectives

# %% [markdown]
# 1. Provide a clear overview of the types and how frequent these complaints occur.
# 2. Idenfity companies and/or product categories receiving the most complaints.
# 3. Analyze response times and resolutions to assess company responsiveness.
# 4. Identify trends over time or across regions that could guide consumer awareness or policy decisions.

# %% [markdown]
# ## Dataset

# %% [markdown]
# The dataset is derived directly from the CFPB official consumer complaint database. The CFPB aggregates complaints submitted by consumers across the United States in a JSON or CSV file. Complaints, regarding financial products such as credit cards, mortgages, bank accounts, and debt collection are included. The dataset also includes details such as complaint date, product type, issue, company response, and consumer demographics where available

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import dataset
df1=pd.read_csv('consumer_complaints.csv', low_memory=False)
df1
# Out:
#        date_received           product                  sub_product  \
# 0         08/30/2013          Mortgage               Other mortgage
# 1         08/30/2013          Mortgage               Other mortgage
# 2         08/30/2013  Credit reporting                          NaN
# 3         08/30/2013      Student loan     Non-federal student loan
# 4         08/30/2013   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    07/01/2014          Mortgage               Other mortgage
# 555953    07/01/2014          Mortgage               Other mortgage
# 555954    07/10/2012          Mortgage  Conventional fixed mortgage
# 555955    04/14/2015   Debt collection                I do not know
# 555956    08/14/2014   Debt collection                I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 sub_issue consumer_complaint_narrative  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                          Account status                          NaN
# 3                      Repaying your loan                          NaN
# 4       Attempted to collect wrong amount                          NaN
# ...                                   ...                          ...
# 555952                                NaN                          NaN
# 555953                                NaN                          NaN
# 555954                                NaN                          NaN
# 555955         Frequent or repeated calls                          NaN
# 555956                   Debt is not mine                          NaN
#
#        company_public_response                          company state zipcode  \
# 0                          NaN                     U.S. Bancorp    CA   95993
# 1                          NaN            Wells Fargo & Company    CA   91104
# 2                          NaN            Wells Fargo & Company    NY   11764
# 3                          NaN          Navient Solutions, Inc.    MD   21402
# 4                          NaN  Resurgent Capital Services L.P.    GA   30106
# ...                        ...                              ...   ...     ...
# 555952                     NaN                  Bank of America   NaN     NaN
# 555953                     NaN     Residential Credit Solutions   NaN     NaN
# 555954                     NaN                   BB&T Financial   NaN     NaN
# 555955                     NaN            Global Recovery Group   NaN     NaN
# 555956                     NaN     CCS Financial Services, Inc.   NaN     NaN
#
#                                  tags consumer_consent_provided submitted_via  \
# 0                                 NaN                       NaN      Referral
# 1                                 NaN                       NaN      Referral
# 2                                 NaN                       NaN   Postal mail
# 3                                 NaN                       NaN         Email
# 4                                 NaN                       NaN           Web
# ...                               ...                       ...           ...
# 555952                            NaN                       NaN      Referral
# 555953  Older American, Servicemember                       NaN      Referral
# 555954                            NaN                       NaN         Phone
# 555955                            NaN                       NaN         Phone
# 555956                            NaN                       NaN         Phone
#
#        date_sent_to_company company_response_to_consumer timely_response  \
# 0                09/03/2013      Closed with explanation             Yes
# 1                09/03/2013      Closed with explanation             Yes
# 2                09/18/2013      Closed with explanation             Yes
# 3                08/30/2013      Closed with explanation             Yes
# 4                08/30/2013      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           07/07/2014      Closed with explanation             Yes
# 555953           07/23/2014      Closed with explanation              No
# 555954           11/18/2013      Closed with explanation             Yes
# 555955           04/14/2015            Untimely response              No
# 555956           08/18/2014      Closed with explanation             Yes
#
#        consumer_disputed?  complaint_id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 18 columns]

# %%
# Derive column information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date_received                 555957 non-null  object
#  1   product                       555957 non-null  object
#  2   sub_product                   397635 non-null  object
#  3   issue                         555957 non-null  object
#  4   sub_issue                     212622 non-null  object
#  5   consumer_complaint_narrative  66806 non-null   object
#  6   company_public_response       85124 non-null   object
#  7   company                       555957 non-null  object
#  8   state                         551070 non-null  object
#  9   zipcode                       551452 non-null  object
#  10  tags                          77959 non-null   object
#  11  consumer_consent_provided     123458 non-null  object
#  12  submitted_via                 555957 non-null  object
#  13  date_sent_to_company          555957 non-null  object
#  14  company_response_to_consumer  555957 non-null  object
#  15  timely_response               555957 non-null  object
#  16  consumer_disputed?            555957 non-null  object
#  17  complaint_id                  555957 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 76.3+ MB

# %% [markdown]
# # Data Cleaning and Initial Data Analysis

# %% [markdown]
# ## Standardize column headers

# %%
df1.columns=df1.columns.str.title()
df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 Company State Zipcode Submitted_Via  \
# 0                          U.S. Bancorp    CA   95993      Referral
# 1                 Wells Fargo & Company    CA   91104      Referral
# 2                 Wells Fargo & Company    NY   11764   Postal mail
# 3               Navient Solutions, Inc.    MD   21402         Email
# 4       Resurgent Capital Services L.P.    GA   30106           Web
# ...                                 ...   ...     ...           ...
# 555952                  Bank of America   NaN     NaN      Referral
# 555953     Residential Credit Solutions   NaN     NaN      Referral
# 555954                   BB&T Financial   NaN     NaN         Phone
# 555955            Global Recovery Group   NaN     NaN         Phone
# 555956     CCS Financial Services, Inc.   NaN     NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 0                2013-09-03      Closed with explanation             Yes
# 1                2013-09-03      Closed with explanation             Yes
# 2                2013-09-18      Closed with explanation             Yes
# 3                2013-08-30      Closed with explanation             Yes
# 4                2013-08-30      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 13 columns]

# %% [markdown]
# ## Changing Data types

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date_Received                 555957 non-null  object
#  1   Product                       555957 non-null  object
#  2   Sub_Product                   397635 non-null  object
#  3   Issue                         555957 non-null  object
#  4   Sub_Issue                     212622 non-null  object
#  5   Consumer_Complaint_Narrative  66806 non-null   object
#  6   Company_Public_Response       85124 non-null   object
#  7   Company                       555957 non-null  object
#  8   State                         551070 non-null  object
#  9   Zipcode                       551452 non-null  object
#  10  Tags                          77959 non-null   object
#  11  Consumer_Consent_Provided     123458 non-null  object
#  12  Submitted_Via                 555957 non-null  object
#  13  Date_Sent_To_Company          555957 non-null  object
#  14  Company_Response_To_Consumer  555957 non-null  object
#  15  Timely_Response               555957 non-null  object
#  16  Consumer_Disputed?            555957 non-null  object
#  17  Complaint_Id                  555957 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 76.3+ MB

# %%
# Change date columns to time-series data type
df1['Date_Received']=pd.to_datetime(df1['Date_Received'])
df1['Date_Sent_To_Company']=pd.to_datetime(df1['Date_Sent_To_Company'])

# %%
# Check to confirm change
df1['Date_Sent_To_Company'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 555957 entries, 0 to 555956
# Series name: Date_Sent_To_Company
# Non-Null Count   Dtype
# --------------   -----
# 555957 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 MB

# %%
# Check to confirm change
df1['Date_Received'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 555957 entries, 0 to 555956
# Series name: Date_Received
# Non-Null Count   Dtype
# --------------   -----
# 555957 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 MB

# %% [markdown]
# ## Missing values

# %%
#Scan whole dataset for missing values; missing values return a True boolean value
df1.isna()
# Out:
#         Date_Received  Product  Sub_Product  Issue  Sub_Issue  \
# 0               False    False        False  False       True
# 1               False    False        False  False       True
# 2               False    False         True  False      False
# 3               False    False        False  False      False
# 4               False    False        False  False      False
# ...               ...      ...          ...    ...        ...
# 555952          False    False        False  False       True
# 555953          False    False        False  False       True
# 555954          False    False        False  False       True
# 555955          False    False        False  False      False
# 555956          False    False        False  False      False
#
#         Consumer_Complaint_Narrative  Company_Public_Response  Company  State  \
# 0                               True                     True    False  False
# 1                               True                     True    False  False
# 2                               True                     True    False  False
# 3                               True                     True    False  False
# 4                               True                     True    False  False
# ...                              ...                      ...      ...    ...
# 555952                          True                     True    False   True
# 555953                          True                     True    False   True
# 555954                          True                     True    False   True
# 555955                          True                     True    False   True
# 555956                          True                     True    False   True
#
#         Zipcode   Tags  Consumer_Consent_Provided  Submitted_Via  \
# 0         False   True                       True          False
# 1         False   True                       True          False
# 2         False   True                       True          False
# 3         False   True                       True          False
# 4         False   True                       True          False
# ...         ...    ...                        ...            ...
# 555952     True   True                       True          False
# 555953     True  False                       True          False
# 555954     True   True                       True          False
# 555955     True   True                       True          False
# 555956     True   True                       True          False
#
#         Date_Sent_To_Company  Company_Response_To_Consumer  Timely_Response  \
# 0                      False                         False            False
# 1                      False                         False            False
# 2                      False                         False            False
# 3                      False                         False            False
# 4                      False                         False            False
# ...                      ...                           ...              ...
# 555952                 False                         False            False
# 555953                 False                         False            False
# 555954                 False                         False            False
# 555955                 False                         False            False
# 555956                 False                         False            False
#
#         Consumer_Disputed?  Complaint_Id
# 0                    False         False
# 1                    False         False
# 2                    False         False
# 3                    False         False
# 4                    False         False
# ...                    ...           ...
# 555952               False         False
# 555953               False         False
# 555954               False         False
# 555955               False         False
# 555956               False         False
#
# [555957 rows x 18 columns]

# %%
# Determine the total number of missing values in each column
df1.isna().sum()
# Out:
# Date_Received                        0
# Product                              0
# Sub_Product                     158322
# Issue                                0
# Sub_Issue                       343335
# Consumer_Complaint_Narrative    489151
# Company_Public_Response         470833
# Company                              0
# State                             4887
# Zipcode                           4505
# Tags                            477998
# Consumer_Consent_Provided       432499
# Submitted_Via                        0
# Date_Sent_To_Company                 0
# Company_Response_To_Consumer         0
# Timely_Response                      0
# Consumer_Disputed?                   0
# Complaint_Id                         0
# dtype: int64

# %%
# Calculate the percentage of missing values in identified columns
df1['Sub_Product'].isna().mean()*100
# Out:
# np.float64(28.47738224359078)

# %% [markdown]
# Percentage <30%. Not enough to drop column

# %%
df1['Sub_Issue'].isna().mean()*100
# Out:
# np.float64(61.755675348992824)

# %% [markdown]
# Percentage >50%. Consider dropping column

# %%
df1['Consumer_Complaint_Narrative'].isna().mean()*100
# Out:
# np.float64(87.9836030484372)

# %% [markdown]
# Column must be dropped. Too many missing values

# %%
df1=df1.drop(['Consumer_Complaint_Narrative'], axis=1)
df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 Sub_Issue Company_Public_Response  \
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                          Account status                     NaN
# 3                      Repaying your loan                     NaN
# 4       Attempted to collect wrong amount                     NaN
# ...                                   ...                     ...
# 555952                                NaN                     NaN
# 555953                                NaN                     NaN
# 555954                                NaN                     NaN
# 555955         Frequent or repeated calls                     NaN
# 555956                   Debt is not mine                     NaN
#
#                                 Company State Zipcode  \
# 0                          U.S. Bancorp    CA   95993
# 1                 Wells Fargo & Company    CA   91104
# 2                 Wells Fargo & Company    NY   11764
# 3               Navient Solutions, Inc.    MD   21402
# 4       Resurgent Capital Services L.P.    GA   30106
# ...                                 ...   ...     ...
# 555952                  Bank of America   NaN     NaN
# 555953     Residential Credit Solutions   NaN     NaN
# 555954                   BB&T Financial   NaN     NaN
# 555955            Global Recovery Group   NaN     NaN
# 555956     CCS Financial Services, Inc.   NaN     NaN
#
#                                  Tags Consumer_Consent_Provided Submitted_Via  \
# 0                                 NaN                       NaN      Referral
# 1                                 NaN                       NaN      Referral
# 2                                 NaN                       NaN   Postal mail
# 3                                 NaN                       NaN         Email
# 4                                 NaN                       NaN           Web
# ...                               ...                       ...           ...
# 555952                            NaN                       NaN      Referral
# 555953  Older American, Servicemember                       NaN      Referral
# 555954                            NaN                       NaN         Phone
# 555955                            NaN                       NaN         Phone
# 555956                            NaN                       NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 0                2013-09-03      Closed with explanation             Yes
# 1                2013-09-03      Closed with explanation             Yes
# 2                2013-09-18      Closed with explanation             Yes
# 3                2013-08-30      Closed with explanation             Yes
# 4                2013-08-30      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 17 columns]

# %%
# Check to see if dropped
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date_Received                 555957 non-null  datetime64[ns]
#  1   Product                       555957 non-null  object
#  2   Sub_Product                   397635 non-null  object
#  3   Issue                         555957 non-null  object
#  4   Sub_Issue                     212622 non-null  object
#  5   Company_Public_Response       85124 non-null   object
#  6   Company                       555957 non-null  object
#  7   State                         551070 non-null  object
#  8   Zipcode                       551452 non-null  object
#  9   Tags                          77959 non-null   object
#  10  Consumer_Consent_Provided     123458 non-null  object
#  11  Submitted_Via                 555957 non-null  object
#  12  Date_Sent_To_Company          555957 non-null  datetime64[ns]
#  13  Company_Response_To_Consumer  555957 non-null  object
#  14  Timely_Response               555957 non-null  object
#  15  Consumer_Disputed?            555957 non-null  object
#  16  Complaint_Id                  555957 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(14)
# memory usage: 72.1+ MB

# %% [markdown]
# Column count reduced to 16. Consumer_Complaint_Narrative removed

# %%
# Comparing Issue and Sub Issue columns to decipher correlation
df1[['Issue', 'Sub_Issue']].head(50)
# Out:
#                                        Issue  \
# 0   Loan modification,collection,foreclosure
# 1   Loan servicing, payments, escrow account
# 2     Incorrect information on credit report
# 3                         Repaying your loan
# 4         False statements or representation
# 5               Application processing delay
# 6              Credit line increase/decrease
# 7                   Deposits and withdrawals
# 8                   Deposits and withdrawals
# 9   Loan modification,collection,foreclosure
# 10     Cont'd attempts collect debt not owed
# 11  Loan servicing, payments, escrow account
# 12            Credit decision / Underwriting
# 13  Application, originator, mortgage broker
# 14                     Communication tactics
# 15                                  Late fee
# 16                     Communication tactics
# 17    Incorrect information on credit report
# 18       Improper contact or sharing of info
# 19    Incorrect information on credit report
# 20                          Billing disputes
# 21       Improper contact or sharing of info
# 22  Loan modification,collection,foreclosure
# 23                     Communication tactics
# 24  Loan modification,collection,foreclosure
# 25  Making/receiving payments, sending money
# 26                  Deposits and withdrawals
# 27                                   Rewards
# 28                     Communication tactics
# 29  Loan modification,collection,foreclosure
# 30    Incorrect information on credit report
# 31                  Deposits and withdrawals
# 32  Loan servicing, payments, escrow account
# 33        False statements or representation
# 34                  Deposits and withdrawals
# 35  Loan servicing, payments, escrow account
# 36                Managing the loan or lease
# 37              Settlement process and costs
# 38     Cont'd attempts collect debt not owed
# 39  Loan servicing, payments, escrow account
# 40     Cont'd attempts collect debt not owed
# 41      Taking/threatening an illegal action
# 42           Disclosure verification of debt
# 43     Identity theft / Fraud / Embezzlement
# 44  Loan modification,collection,foreclosure
# 45  Loan modification,collection,foreclosure
# 46    Incorrect information on credit report
# 47     Cont'd attempts collect debt not owed
# 48    Incorrect information on credit report
# 49     Customer service / Customer relations
#
#                                 Sub_Issue
# 0                                     NaN
# 1                                     NaN
# 2                          Account status
# 3                      Repaying your loan
# 4       Attempted to collect wrong amount
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                          Debt was paid
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14              Called outside of 8am-9pm
# 15                                    NaN
# 16  Used obscene/profane/abusive language
# 17     Reinserted previously deleted info
# 18  Talked to a third party about my debt
# 19                Information is not mine
# 20                                    NaN
# 21  Talked to a third party about my debt
# 22                                    NaN
# 23              Called outside of 8am-9pm
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28             Frequent or repeated calls
# 29                                    NaN
# 30     Reinserted previously deleted info
# 31                                    NaN
# 32                                    NaN
# 33      Attempted to collect wrong amount
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                    NaN
# 38                       Debt is not mine
# 39                                    NaN
# 40                       Debt is not mine
# 41      Threatened to sue on too old debt
# 42   Not given enough info to verify debt
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                         Account status
# 47                       Debt is not mine
# 48     Reinserted previously deleted info
# 49                                    NaN

# %% [markdown]
# Sub-Issue is a sub-category to Issue and contains too many missing values. Does not impact data directly. Safe to drop

# %%
df1['Company_Public_Response'].isna().mean()*100
# Out:
# np.float64(84.688743913648)

# %% [markdown]
# Getting dropped!

# %%
# Drop Sub-issue, Company public response column
df1=df1.drop(['Sub_Issue'],axis=1)
df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue Company_Public_Response  \
# 0       Loan modification,collection,foreclosure                     NaN
# 1       Loan servicing, payments, escrow account                     NaN
# 2         Incorrect information on credit report                     NaN
# 3                             Repaying your loan                     NaN
# 4             False statements or representation                     NaN
# ...                                          ...                     ...
# 555952  Loan modification,collection,foreclosure                     NaN
# 555953  Loan servicing, payments, escrow account                     NaN
# 555954  Loan modification,collection,foreclosure                     NaN
# 555955                     Communication tactics                     NaN
# 555956     Cont'd attempts collect debt not owed                     NaN
#
#                                 Company State Zipcode  \
# 0                          U.S. Bancorp    CA   95993
# 1                 Wells Fargo & Company    CA   91104
# 2                 Wells Fargo & Company    NY   11764
# 3               Navient Solutions, Inc.    MD   21402
# 4       Resurgent Capital Services L.P.    GA   30106
# ...                                 ...   ...     ...
# 555952                  Bank of America   NaN     NaN
# 555953     Residential Credit Solutions   NaN     NaN
# 555954                   BB&T Financial   NaN     NaN
# 555955            Global Recovery Group   NaN     NaN
# 555956     CCS Financial Services, Inc.   NaN     NaN
#
#                                  Tags Consumer_Consent_Provided Submitted_Via  \
# 0                                 NaN                       NaN      Referral
# 1                                 NaN                       NaN      Referral
# 2                                 NaN                       NaN   Postal mail
# 3                                 NaN                       NaN         Email
# 4                                 NaN                       NaN           Web
# ...                               ...                       ...           ...
# 555952                            NaN                       NaN      Referral
# 555953  Older American, Servicemember                       NaN      Referral
# 555954                            NaN                       NaN         Phone
# 555955                            NaN                       NaN         Phone
# 555956                            NaN                       NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 0                2013-09-03      Closed with explanation             Yes
# 1                2013-09-03      Closed with explanation             Yes
# 2                2013-09-18      Closed with explanation             Yes
# 3                2013-08-30      Closed with explanation             Yes
# 4                2013-08-30      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 16 columns]

# %%
df1=df1.drop(['Company_Public_Response'],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date_Received                 555957 non-null  datetime64[ns]
#  1   Product                       555957 non-null  object
#  2   Sub_Product                   397635 non-null  object
#  3   Issue                         555957 non-null  object
#  4   Company                       555957 non-null  object
#  5   State                         551070 non-null  object
#  6   Zipcode                       551452 non-null  object
#  7   Tags                          77959 non-null   object
#  8   Consumer_Consent_Provided     123458 non-null  object
#  9   Submitted_Via                 555957 non-null  object
#  10  Date_Sent_To_Company          555957 non-null  datetime64[ns]
#  11  Company_Response_To_Consumer  555957 non-null  object
#  12  Timely_Response               555957 non-null  object
#  13  Consumer_Disputed?            555957 non-null  object
#  14  Complaint_Id                  555957 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(12)
# memory usage: 63.6+ MB

# %% [markdown]
# Column count reduced from 16 to 14

# %%
df1['Tags'].isna().mean()*100
# Out:
# np.float64(85.97751264935958)

# %%
df1=df1.drop(['Tags'],axis=1)

# %%
df1['Consumer_Consent_Provided'].isna().mean()*100
# Out:
# np.float64(77.79360634005867)

# %%
df1=df1.drop(['Consumer_Consent_Provided'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date_Received                 555957 non-null  datetime64[ns]
#  1   Product                       555957 non-null  object
#  2   Sub_Product                   397635 non-null  object
#  3   Issue                         555957 non-null  object
#  4   Company                       555957 non-null  object
#  5   State                         551070 non-null  object
#  6   Zipcode                       551452 non-null  object
#  7   Submitted_Via                 555957 non-null  object
#  8   Date_Sent_To_Company          555957 non-null  datetime64[ns]
#  9   Company_Response_To_Consumer  555957 non-null  object
#  10  Timely_Response               555957 non-null  object
#  11  Consumer_Disputed?            555957 non-null  object
#  12  Complaint_Id                  555957 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(10)
# memory usage: 55.1+ MB

# %%
# Missing values left
df1.isna().sum()
# Out:
# Date_Received                        0
# Product                              0
# Sub_Product                     158322
# Issue                                0
# Company                              0
# State                             4887
# Zipcode                           4505
# Submitted_Via                        0
# Date_Sent_To_Company                 0
# Company_Response_To_Consumer         0
# Timely_Response                      0
# Consumer_Disputed?                   0
# Complaint_Id                         0
# dtype: int64

# %%
# Determine items in sub-product to consider removal
df1['Sub_Product'].value_counts()
# Out:
# Sub_Product
# Other mortgage                            74319
# Conventional fixed mortgage               57182
# Checking account                          44369
# Other (i.e. phone, health club, etc.)     29617
# I do not know                             21634
# Conventional adjustable mortgage (ARM)    20941
# Credit card                               20825
# FHA mortgage                              19152
# Non-federal student loan                  17969
# Medical                                   13297
# Vehicle loan                              12168
# Other bank product/service                10895
# Payday loan                                9684
# Home equity loan or line of credit         8944
# Installment loan                           5279
# Savings account                            3996
# VA mortgage                                3735
# Mortgage                                   3433
# (CD) Certificate of deposit                2839
# Auto                                       2523
# International money transfer               2035
# Federal student loan                       1786
# Domestic (US) money transfer               1777
# Vehicle lease                              1639
# Reverse mortgage                           1537
# Personal line of credit                    1516
# General purpose card                       1165
# Second mortgage                             665
# Cashing a check without an account          464
# Title loan                                  329
# Payroll card                                313
# Mobile wallet                               240
# Gift or merchant card                       225
# Government benefit payment card             225
# Check cashing                               156
# ID prepaid card                             144
# Debt settlement                             142
# Other special purpose card                  123
# Money order                                  71
# Pawn loan                                    59
# Credit repair                                54
# Travelerâs/Cashierâs checks              51
# Foreign currency exchange                    43
# Refund anticipation check                    40
# Transit card                                 30
# Electronic Benefit Transfer / EBT card        5
# Name: count, dtype: int64

# %% [markdown]
# Column has several unique values; cannot back or forward fill

# %%
# Locate where the missing values in the State column are to discover trends to facilitate IDA
state_missing=df1.loc[df1['State'].isna()]
state_missing
# Out:
#        Date_Received                  Product                   Sub_Product  \
# 365       2013-09-10          Money transfers  International money transfer
# 868       2013-09-10          Money transfers  Domestic (US) money transfer
# 939       2013-09-25  Bank account or service              Checking account
# 1026      2013-09-02                 Mortgage   Conventional fixed mortgage
# 2043      2013-09-03  Bank account or service              Checking account
# ...              ...                      ...                           ...
# 555952    2014-07-01                 Mortgage                Other mortgage
# 555953    2014-07-01                 Mortgage                Other mortgage
# 555954    2012-07-10                 Mortgage   Conventional fixed mortgage
# 555955    2015-04-14          Debt collection                 I do not know
# 555956    2014-08-14          Debt collection                 I do not know
#
#                                            Issue  \
# 365        Money was not available when promised
# 868                     Other transaction issues
# 939                     Deposits and withdrawals
# 1026    Loan servicing, payments, escrow account
# 2043     Account opening, closing, or management
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                  Company State Zipcode Submitted_Via  \
# 365           TD Bank US Holding Company   NaN     NaN           Web
# 868     HSBC North America Holdings Inc.   NaN     NaN           Web
# 939              New York Community Bank   NaN     NaN         Phone
# 1026                Ditech Financial LLC   NaN     NaN           Web
# 2043                            Citibank   NaN     NaN      Referral
# ...                                  ...   ...     ...           ...
# 555952                   Bank of America   NaN     NaN      Referral
# 555953      Residential Credit Solutions   NaN     NaN      Referral
# 555954                    BB&T Financial   NaN     NaN         Phone
# 555955             Global Recovery Group   NaN     NaN         Phone
# 555956      CCS Financial Services, Inc.   NaN     NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 365              2013-09-10      Closed with explanation             Yes
# 868              2013-09-11      Closed with explanation             Yes
# 939              2013-09-25      Closed with explanation             Yes
# 1026             2013-09-03      Closed with explanation             Yes
# 2043             2013-09-06  Closed with monetary relief             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id
# 365                   Yes        521653
# 868                    No        522003
# 939                    No        541527
# 1026                   No        514861
# 2043                   No        513291
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [4887 rows x 13 columns]

# %%
# Determine the percentage of missing values in State column
df1['State'].isna().mean()*100
# Out:
# np.float64(0.8790248166674761)

# %% [markdown]
# Keep State Column

# %% [markdown]
# ## Missing Values: Justification

# %% [markdown]
# 1. Collectors may not be able to collect certain personal information
# 2. There were columns (Sub-Issue) that depended on others (Issue). Sub_Issue was removed due to a high count of missing values
# 3. Forms filled to generate dataset were not thoroughly filled
#
# Values in columns had to be dropped for the following reasons:
# 1. To avoid visualisations that could be misleading
# 2. To avoid a bias in statistical calculations of the mean, median, etc.
# 3. Columns which had several missing values would not qualify as features during model training

# %% [markdown]
# ## Duplicates

# %%
# Check for duplicates
df1.duplicated().any()
# Out:
# np.False_

# %%
df1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 555952    False
# 555953    False
# 555954    False
# 555955    False
# 555956    False
# Length: 555957, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### No duplicates found

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555957 entries, 0 to 555956
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date_Received                 555957 non-null  datetime64[ns]
#  1   Product                       555957 non-null  object
#  2   Sub_Product                   397635 non-null  object
#  3   Issue                         555957 non-null  object
#  4   Company                       555957 non-null  object
#  5   State                         551070 non-null  object
#  6   Zipcode                       551452 non-null  object
#  7   Submitted_Via                 555957 non-null  object
#  8   Date_Sent_To_Company          555957 non-null  datetime64[ns]
#  9   Company_Response_To_Consumer  555957 non-null  object
#  10  Timely_Response               555957 non-null  object
#  11  Consumer_Disputed?            555957 non-null  object
#  12  Complaint_Id                  555957 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(10)
# memory usage: 55.1+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 Company State Zipcode Submitted_Via  \
# 0                          U.S. Bancorp    CA   95993      Referral
# 1                 Wells Fargo & Company    CA   91104      Referral
# 2                 Wells Fargo & Company    NY   11764   Postal mail
# 3               Navient Solutions, Inc.    MD   21402         Email
# 4       Resurgent Capital Services L.P.    GA   30106           Web
# ...                                 ...   ...     ...           ...
# 555952                  Bank of America   NaN     NaN      Referral
# 555953     Residential Credit Solutions   NaN     NaN      Referral
# 555954                   BB&T Financial   NaN     NaN         Phone
# 555955            Global Recovery Group   NaN     NaN         Phone
# 555956     CCS Financial Services, Inc.   NaN     NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 0                2013-09-03      Closed with explanation             Yes
# 1                2013-09-03      Closed with explanation             Yes
# 2                2013-09-18      Closed with explanation             Yes
# 3                2013-08-30      Closed with explanation             Yes
# 4                2013-08-30      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id
# 0                     Yes        511074
# 1                     Yes        511080
# 2                      No        510473
# 3                     Yes        510326
# 4                     Yes        511067
# ...                   ...           ...
# 555952                 No        919529
# 555953                 No        918447
# 555954                 No        114550
# 555955                 No       1329963
# 555956                 No        984116
#
# [555957 rows x 13 columns]

# %%
df1.describe()
# Out:
#                        Date_Received           Date_Sent_To_Company  \
# count                         555957                         555957
# mean   2014-06-28 00:45:51.648778496  2014-07-02 16:32:26.170657280
# min              2011-12-01 00:00:00            2011-12-01 00:00:00
# 25%              2013-08-09 00:00:00            2013-08-19 00:00:00
# 50%              2014-08-07 00:00:00            2014-08-12 00:00:00
# 75%              2015-06-28 00:00:00            2015-07-01 00:00:00
# max              2016-04-25 00:00:00            2016-04-25 00:00:00
# std                              NaN                            NaN
#
#        Complaint_Id
# count  5.559570e+05
# mean   9.600510e+05
# min    1.000000e+00
# 25%    4.863230e+05
# 50%    9.737830e+05
# 75%    1.441702e+06
# max    1.895894e+06
# std    5.504296e+05

# %% [markdown]
# 1. Which financial products generate the most consumer complaints?

# %%
fin_prod_comp=df1.groupby('Product')['Issue'].value_counts()
fin_prod_comp
# Out:
# Product                  Issue
# Bank account or service  Account opening, closing, or management     26661
#                          Deposits and withdrawals                    17195
#                          Problems caused by my funds being low        9037
#                          Making/receiving payments, sending money     5350
#                          Using a debit or ATM card                    4320
#                                                                      ...
# Student loan             Dealing with my lender or servicer           5904
#                          Can't repay my loan                          3920
#                          Repaying your loan                           3832
#                          Problems when you are unable to pay          1701
#                          Getting a loan                                482
# Name: count, Length: 108, dtype: int64

# %%
fin_prod_subcomp=df1.groupby('Sub_Product')['Issue'].value_counts()
fin_prod_subcomp
# Out:
# Sub_Product                  Issue
# (CD) Certificate of deposit  Account opening, closing, or management     2057
#                              Deposits and withdrawals                     646
#                              Making/receiving payments, sending money     113
#                              Problems caused by my funds being low         17
#                              Using a debit or ATM card                      6
#                                                                          ...
# Vehicle lease                Shopping for a loan or lease                 117
# Vehicle loan                 Managing the loan or lease                  6490
#                              Problems when you are unable to pay         3191
#                              Taking out the loan or lease                1660
#                              Shopping for a loan or lease                 827
# Name: count, Length: 289, dtype: int64

# %%
# Convert series to DataFrame
fin_prod_df = fin_prod_comp.reset_index(name='Count')
plt.figure(figsize=(10,8))
sns.barplot(data=fin_prod_df, y='Product', x='Count', palette='viridis', hue='Product', legend=False)
plt.title('Consumer complaints by Financial Product')
plt.ylabel('Products')
plt.xlabel('Consumer Complaints')
# Out:
# Text(0.5, 0, 'Consumer Complaints')

# %% [markdown]
# 2. What are the most common issues reported by consumers?

# %%
# Highlight the top ten common issues
df1['Issue'].value_counts().head(10)
# Out:
# Issue
# Loan modification,collection,foreclosure    97191
# Incorrect information on credit report      66718
# Loan servicing, payments, escrow account    60375
# Cont'd attempts collect debt not owed       42285
# Account opening, closing, or management     26661
# Communication tactics                       18293
# Disclosure verification of debt             18292
# Deposits and withdrawals                    17195
# Application, originator, mortgage broker    13306
# Billing disputes                            11042
# Name: count, dtype: int64

# %%
# Top 5 on a pie chart
comm_issue=df1['Issue'].value_counts().head(5)
comm_issue
# Out:
# Issue
# Loan modification,collection,foreclosure    97191
# Incorrect information on credit report      66718
# Loan servicing, payments, escrow account    60375
# Cont'd attempts collect debt not owed       42285
# Account opening, closing, or management     26661
# Name: count, dtype: int64

# %%
# Draw pie chart
plt.figure(figsize=(10,8))
plt.pie(comm_issue, autopct='%1.1f%%')
plt.title('Top 5 consumer complaints')
plt.legend(title='Complaints', labels=comm_issue.index, bbox_to_anchor=(1, 0, 0.5, 1), loc='upper right')

# %% [markdown]
# 3. How responsive are companies in addressing complaints, and what is the distribution of response times?

# %%
# General timely responses (counts)
df1['Timely_Response'].value_counts()
# Out:
# Timely_Response
# Yes    541909
# No      14048
# Name: count, dtype: int64

# %%
df1['Company'].value_counts()
# Out:
# Company
# Bank of America                55998
# Wells Fargo & Company          42024
# JPMorgan Chase & Co.           33881
# Equifax                        31828
# Experian                       30905
#                                ...
# Nations Trust Mortgage Corp        1
# Alliance Capital Corp.             1
# Tsarouhis Law Group, LLC           1
# AAA COLLECTORS, INC.               1
# Turbo Cash, LLC                    1
# Name: count, Length: 3605, dtype: int64

# %%
# For each company, group responses
df1.groupby('Company')['Timely_Response'].value_counts().sort_values(ascending=False)
# Out:
# Company                          Timely_Response
# Bank of America                  Yes                54446
# Wells Fargo & Company            Yes                41651
# JPMorgan Chase & Co.             Yes                33798
# Equifax                          Yes                31828
# Experian                         Yes                30899
#                                                     ...
# Works & Lentz, Inc               No                     1
# 1st Capital Mortgage, LLC        Yes                    1
# World-Wide Communication Center  Yes                    1
# World Wide Pay Day Advance, Inc  No                     1
# World Wide Land Transfer, Inc.   Yes                    1
# Name: count, Length: 5254, dtype: int64

# %%
top_20_timely=df1.groupby('Company')['Timely_Response'].value_counts().sort_values(ascending=False).head(10)
top_20_timely
# Out:
# Company                                 Timely_Response
# Bank of America                         Yes                54446
# Wells Fargo & Company                   Yes                41651
# JPMorgan Chase & Co.                    Yes                33798
# Equifax                                 Yes                31828
# Experian                                Yes                30899
# TransUnion Intermediate Holdings, Inc.  Yes                25534
# Citibank                                Yes                25226
# Ocwen                                   Yes                20439
# Capital One                             Yes                15569
# Nationstar Mortgage                     Yes                13125
# Name: count, dtype: int64

# %%
# Distribution of response times in days
df1['time_response'].describe()
# Out:
# count    555957.000000
# mean          4.657344
# std          17.200280
# min          -1.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max         993.000000
# Name: time_response, dtype: float64

# %% [markdown]
# Most companies have a timely response time

# %%
# Calculate average response time
avg_response=df1['Date_Received'].mean()
print('The average response time is', avg_response)
# Out:
# The average response time is 2014-06-28 00:45:51.648778496

# %%
# Time series chart to visualize the trend of responses within a period of time

# %% [markdown]
# 4. Are there noticeable trends in complaints over time or by geographic location?

# %%
df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 Company State Zipcode Submitted_Via  \
# 0                          U.S. Bancorp    CA   95993      Referral
# 1                 Wells Fargo & Company    CA   91104      Referral
# 2                 Wells Fargo & Company    NY   11764   Postal mail
# 3               Navient Solutions, Inc.    MD   21402         Email
# 4       Resurgent Capital Services L.P.    GA   30106           Web
# ...                                 ...   ...     ...           ...
# 555952                  Bank of America   NaN     NaN      Referral
# 555953     Residential Credit Solutions   NaN     NaN      Referral
# 555954                   BB&T Financial   NaN     NaN         Phone
# 555955            Global Recovery Group   NaN     NaN         Phone
# 555956     CCS Financial Services, Inc.   NaN     NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer  ...  340  601  714  \
# 0                2013-09-03      Closed with explanation  ...  340  601  714
# 1                2013-09-03      Closed with explanation  ...  340  601  714
# 2                2013-09-18      Closed with explanation  ...  340  601  714
# 3                2013-08-30      Closed with explanation  ...  340  601  714
# 4                2013-08-30      Closed with explanation  ...  340  601  714
# ...                     ...                          ...  ...  ...  ...  ...
# 555952           2014-07-07      Closed with explanation  ...  340  601  714
# 555953           2014-07-23      Closed with explanation  ...  340  601  714
# 555954           2013-11-18      Closed with explanation  ...  340  601  714
# 555955           2015-04-14            Untimely response  ...  340  601  714
# 555956           2014-08-18      Closed with explanation  ...  340  601  714
#
#         541  352  832  711  481  496  time_response
# 0       541  352  832  711  481  496              4
# 1       541  352  832  711  481  496              4
# 2       541  352  832  711  481  496             19
# 3       541  352  832  711  481  496              0
# 4       541  352  832  711  481  496              0
# ...     ...  ...  ...  ...  ...  ...            ...
# 555952  541  352  832  711  481  496              6
# 555953  541  352  832  711  481  496             22
# 555954  541  352  832  711  481  496            496
# 555955  541  352  832  711  481  496              0
# 555956  541  352  832  711  481  496              4
#
# [555957 rows x 436 columns]

# %%
state_counts = df1['State'].value_counts().reset_index()
state_counts.columns = ['State', 'Complaint_Count']


# Change state name to numerical positions
state_counts['State_Index'] = np.arange(len(state_counts))

# Plot scatterplot
plt.figure(figsize=(14, 6))
plt.scatter(state_counts['State_Index'], state_counts['Complaint_Count'], s=60)
plt.xticks(state_counts['State_Index'], state_counts['State'], rotation=90)
plt.title('Scatterplot of Complaint Volume by State')
plt.xlabel('State')
plt.ylabel('Number of Complaints')
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# California has the most number of complaints

# %%
# Identify the number of complaints by year
# Extract year and count complaints per year
yearly_complaints = df1.groupby(df1['Date_Received'].dt.year).size().reset_index(name='Issue')

# Line chart by year
plt.figure(figsize=(10,6))
plt.plot(yearly_complaints['Date_Received'], yearly_complaints['Issue'], marker='o', linestyle='-')
plt.title('Complaints per Year')
plt.xlabel('Year')
plt.ylabel('Number of Complaints')
plt.xticks(yearly_complaints['Date_Received'])  # Show every year
plt.grid(True)
plt.show()

# %% [markdown]
# 2011 received the least issues whilst 2015 received the most number of issues. Issues sharply declined in 2016

# %%
# Identify columns where the column name is numeric
numeric_cols = [col for col in df1.columns if str(col).isdigit()]

# Find numeric columns where all values match the column header
cols_to_drop = [col for col in numeric_cols if (df1[col] == int(col)).all()]

# Drop them
df1 = df1.drop(columns=cols_to_drop)

df1
# Out:
#        Date_Received           Product                  Sub_Product  \
# 0         2013-08-30          Mortgage               Other mortgage
# 1         2013-08-30          Mortgage               Other mortgage
# 2         2013-08-30  Credit reporting                          NaN
# 3         2013-08-30      Student loan     Non-federal student loan
# 4         2013-08-30   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    2014-07-01          Mortgage               Other mortgage
# 555953    2014-07-01          Mortgage               Other mortgage
# 555954    2012-07-10          Mortgage  Conventional fixed mortgage
# 555955    2015-04-14   Debt collection                I do not know
# 555956    2014-08-14   Debt collection                I do not know
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 Company State Zipcode Submitted_Via  \
# 0                          U.S. Bancorp    CA   95993      Referral
# 1                 Wells Fargo & Company    CA   91104      Referral
# 2                 Wells Fargo & Company    NY   11764   Postal mail
# 3               Navient Solutions, Inc.    MD   21402         Email
# 4       Resurgent Capital Services L.P.    GA   30106           Web
# ...                                 ...   ...     ...           ...
# 555952                  Bank of America   NaN     NaN      Referral
# 555953     Residential Credit Solutions   NaN     NaN      Referral
# 555954                   BB&T Financial   NaN     NaN         Phone
# 555955            Global Recovery Group   NaN     NaN         Phone
# 555956     CCS Financial Services, Inc.   NaN     NaN         Phone
#
#        Date_Sent_To_Company Company_Response_To_Consumer Timely_Response  \
# 0                2013-09-03      Closed with explanation             Yes
# 1                2013-09-03      Closed with explanation             Yes
# 2                2013-09-18      Closed with explanation             Yes
# 3                2013-08-30      Closed with explanation             Yes
# 4                2013-08-30      Closed with explanation             Yes
# ...                     ...                          ...             ...
# 555952           2014-07-07      Closed with explanation             Yes
# 555953           2014-07-23      Closed with explanation              No
# 555954           2013-11-18      Closed with explanation             Yes
# 555955           2015-04-14            Untimely response              No
# 555956           2014-08-18      Closed with explanation             Yes
#
#        Consumer_Disputed?  Complaint_Id  -1  time_response
# 0                     Yes        511074  -1              4
# 1                     Yes        511080  -1              4
# 2                      No        510473  -1             19
# 3                     Yes        510326  -1              0
# 4                     Yes        511067  -1              0
# ...                   ...           ...  ..            ...
# 555952                 No        919529  -1              6
# 555953                 No        918447  -1             22
# 555954                 No        114550  -1            496
# 555955                 No       1329963  -1              0
# 555956                 No        984116  -1              4
#
# [555957 rows x 15 columns]

# %% [markdown]
# 5. Which companies resolve complaints satisfactorily on a consistent basis, and which struggle?

# %%
df1['Company_Response_To_Consumer'].value_counts()
# Out:
# Company_Response_To_Consumer
# Closed with explanation            404293
# Closed with non-monetary relief     70237
# Closed with monetary relief         38262
# Closed without relief               17909
# Closed                              13399
# Closed with relief                   5305
# In progress                          3763
# Untimely response                    2789
# Name: count, dtype: int64

# %%
cust_sats=df1.groupby('Company')['Company_Response_To_Consumer'].value_counts()
cust_sats.sort_values(ascending=False).head(50)
# Out:
# Company                                 Company_Response_To_Consumer
# Bank of America                         Closed with explanation            37212
# Wells Fargo & Company                   Closed with explanation            32809
# JPMorgan Chase & Co.                    Closed with explanation            25722
# Equifax                                 Closed with explanation            23877
# TransUnion Intermediate Holdings, Inc.  Closed with explanation            18805
# Ocwen                                   Closed with explanation            18245
# Experian                                Closed with explanation            16899
# Citibank                                Closed with explanation            15700
# Experian                                Closed with non-monetary relief    12776
# Nationstar Mortgage                     Closed with explanation            12466
# Capital One                             Closed with explanation            10068
# Ditech Financial LLC                    Closed with explanation             7756
# Equifax                                 Closed with non-monetary relief     7645
# Bank of America                         Closed with non-monetary relief     7640
# U.S. Bancorp                            Closed with explanation             6640
# TransUnion Intermediate Holdings, Inc.  Closed with non-monetary relief     6394
# Navient Solutions, Inc.                 Closed with explanation             6276
# HSBC North America Holdings Inc.        Closed with explanation             5139
# PNC Bank N.A.                           Closed with explanation             5071
# Synchrony Financial                     Closed with explanation             4869
# Citibank                                Closed with monetary relief         4689
# Bank of America                         Closed without relief               4531
#                                         Closed with monetary relief         4413
# Select Portfolio Servicing, Inc         Closed with explanation             4172
# Encore Capital Group                    Closed with explanation             4140
# Amex                                    Closed with explanation             3812
# JPMorgan Chase & Co.                    Closed with monetary relief         3253
# Wells Fargo & Company                   Closed with monetary relief         3045
# SunTrust Banks, Inc.                    Closed with explanation             3021
# Discover                                Closed with explanation             2984
# Wells Fargo & Company                   Closed without relief               2842
# Citibank                                Closed with non-monetary relief     2758
# Synchrony Financial                     Closed with monetary relief         2594
# Seterus, Inc.                           Closed with explanation             2590
# Capital One                             Closed with monetary relief         2499
# TD Bank US Holding Company              Closed with explanation             2453
# ERC                                     Closed with non-monetary relief     2425
# Wells Fargo & Company                   Closed with non-monetary relief     2362
# BB&T Financial                          Closed with explanation             2267
# Encore Capital Group                    Closed with non-monetary relief     2071
# JPMorgan Chase & Co.                    Closed without relief               2011
# M&T Bank Corporation                    Closed with explanation             1971
# Citizens Financial Group, Inc.          Closed with explanation             1941
# Santander Consumer USA Holdings Inc     Closed with explanation             1863
# Fifth Third Financial Corporation       Closed with explanation             1857
# Expert Global Solutions, Inc.           Closed with explanation             1729
# Portfolio Recovery Associates, Inc.     Closed with explanation             1708
#                                         Closed with non-monetary relief     1678
# Ally Financial Inc.                     Closed with explanation             1671
# Barclays PLC                            Closed with explanation             1538
# Name: count, dtype: int64

# %%
# Cross-tab between Timely Response and Consumer Disputed
ct = pd.crosstab(df1['Timely_Response'], df1['Consumer_Disputed?'])

plt.figure(figsize=(8,6))
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
plt.title('Heatmap: Timely Response vs Consumer Disputed')
plt.xlabel('Consumer Disputed?')
plt.ylabel('Timely Response?')
plt.show()

# %% [markdown]
# A lot of consumers have their issues timely resolved, but are not happy with the resolution!

# %%
# Determine which company responds to complaints consistently
# Cross-tab between company, timely response, and dispute outcome
company_ct = pd.crosstab(df1['Company'],[df1['Timely_Response'], df1['Consumer_Disputed?']])

plt.figure(figsize=(10,5))
sns.heatmap(company_ct, annot=True, fmt='d', cmap='Oranges')
plt.title('Company Performance: Timely Response vs Consumer Disputes')
plt.ylabel('Company')
plt.xlabel('Timely Response / Disputed')
plt.show()

# %%
Can patterns in the complaints provide insights into systemic issues in the financial sector?
