# %% [markdown]
# # Project Introduction

# %% [markdown]
# This project aims to analyse Montgomery County’s crime dataset, to identify key patterns and trends, and raise contextual risk causes. This is so that insights, recommendations and strategies could be provided to reduce the incidence of crime, ultimately increasing public safety in the County

# %% [markdown]
# # Problem Statement

# %% [markdown]
# The MCPD has the resources and the inter-agency relationships to patrol communities, investigate incidents, and disrupt criminal activity; however, due to an ever-changing crime landscape, there are still question marks over which categories of crime will increase or decrease from month to month or year to year. It is also hard to determine with precision where the hotspots are within each police district, which limits the ability to design targeted interventions. The dataset is also limited regarding which crimes have the most impact on victims; a concerning oversight.
# These limitations relate to a problem in the quality of the dataset itself: missing values, inconsistent column headers, improper data types, and geographic coordinates that are not accurate collectively undermine confidence in any conclusions drawn from the data.

# %% [markdown]
# # Research Questions

# %% [markdown]
# 1. What is the geographical composition of the county, by police district?
# 2. Which crimes impact victims the most?
# 3. Which offence code records the highest crime entries, and which city are they occurring?
# 4. How has the overall crime frequency evolved between 2018 and 2022, and what seasonal or monthly patterns can be observed during this period?
# 5. How does crime composition differ across agencies and time?

# %% [markdown]
# # Project Objectives

# %% [markdown]
# 1. To spatially map out the geographical boundaries of all police districts in Montgomery County.
# 2. To identify the top three crime categories that most severely affect victims by analysing crime frequency and severity indicators within the dataset.
# 3. Determine the city that records the highest number of incidents under offence code 2305 by performing city level counts and comparisons.
# 4. To analyze the monthly and yearly crime trends from 2018 to 2022 for any major increases, decreases, or seasonal patterns within that time period.

# %% [markdown]
# # Dataset

# %% [markdown]
# Police officers in the county file dispatched incident reports. The MCPD Records Division receives, verifies and codes those reports and maintains the department’s records. These records are in the public domain on their website and contain detailed records of reported crimes between the years 2018 and 2022. The data is in a structured format as a CSV file where each row represents a reported crime and each column represents specific information about the incident for example, date, time, location, police district etc.

# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as st
import numpy as np

# %%
# upload dataset
df1=pd.read_csv('Crime_Dataset_Coursework1-1.csv', low_memory=False)
df1
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS Code  Victims             Crime Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime Name3 Police District Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Street Prefix     Street Name Street Suffix  Street Type  \
# 0                NaN     MIDDLEBROOK           NaN           RD
# 1                NaN        WOODMONT           NaN          AVE
# 2                NaN        WOODMONT           NaN          AVE
# 3                NaN  QUINCE ORCHARD           NaN           RD
# 4                NaN        FALSTONE           NaN          AVE
# ...              ...             ...           ...          ...
# 306089           NaN       TRANSHIRE           NaN           RD
# 306090           NaN        ATHERTON           NaN           DR
# 306091           NaN       BALTUSROL           NaN           DR
# 306092           NaN          FENTON           NaN           ST
# 306093           NaN    NEWPORT MILL           NaN           RD
#
#                Start_Date_Time           End_Date_Time   Latitude  Longitude  \
# 0       08/23/2018 09:52:00 PM                     NaN  39.177744 -77.265619
# 1       03/30/2018 01:01:00 AM                     NaN  38.992693 -77.097063
# 2       03/30/2018 01:01:00 AM                     NaN  38.992693 -77.097063
# 3       06/14/2018 10:26:00 PM  06/15/2018 03:00:00 AM  39.147954 -77.218189
# 4       09/02/2018 11:30:00 PM  09/03/2018 12:30:00 AM  38.966174 -77.096561
# ...                        ...                     ...        ...        ...
# 306089  02/20/2021 08:00:00 PM                     NaN  39.172701 -77.197340
# 306090  05/06/2021 03:15:00 AM                     NaN  39.059672 -77.075995
# 306091  05/05/2021 10:38:00 PM                     NaN  39.199722 -77.273039
# 306092  03/13/2021 01:35:00 PM                     NaN  38.985813 -77.022915
# 306093  04/18/2021 04:00:00 PM  04/19/2021 12:00:00 PM  39.037115 -77.072485
#
#        Police District Number             Location
# 0                          5D  (39.1777, -77.2656)
# 1                          2D  (38.9927, -77.0971)
# 2                          2D  (38.9927, -77.0971)
# 3                          6D   (39.148, -77.2182)
# 4                          2D  (38.9662, -77.0966)
# ...                       ...                  ...
# 306089                     6D  (39.1727, -77.1973)
# 306090                     4D   (39.0597, -77.076)
# 306091                     5D   (39.1997, -77.273)
# 306092                     3D  (38.9858, -77.0229)
# 306093                     2D  (39.0371, -77.0725)
#
# [306094 rows x 30 columns]

# %%
# Derive column information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306094 entries, 0 to 306093
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             306094 non-null  int64
#  1   Offence Code            306094 non-null  object
#  2   CR Number               306094 non-null  int64
#  3   Dispatch Date / Time    257065 non-null  object
#  4   NIBRS Code              306094 non-null  object
#  5   Victims                 306094 non-null  int64
#  6   Crime Name1             305822 non-null  object
#  7   Crime Name2             305822 non-null  object
#  8   Crime Name3             305822 non-null  object
#  9   Police District Name    306000 non-null  object
#  10  Block Address           279888 non-null  object
#  11  City                    304818 non-null  object
#  12  State                   306094 non-null  object
#  13  Zip Code                302915 non-null  float64
#  14  Agency                  306094 non-null  object
#  15  Place                   306094 non-null  object
#  16  Sector                  304564 non-null  object
#  17  Beat                    304564 non-null  object
#  18  PRA                     305855 non-null  object
#  19  Address Number          279985 non-null  float64
#  20  Street Prefix           13631 non-null   object
#  21  Street Name             306093 non-null  object
#  22  Street Suffix           5432 non-null    object
#  23  Street Type             305755 non-null  object
#  24  Start_Date_Time         306094 non-null  object
#  25  End_Date_Time           144436 non-null  object
#  26  Latitude                306094 non-null  float64
#  27  Longitude               306094 non-null  float64
#  28  Police District Number  306094 non-null  object
#  29  Location                306094 non-null  object
# dtypes: float64(4), int64(3), object(23)
# memory usage: 70.1+ MB

# %% [markdown]
# ## Data Cleaning and Initial Data Analysis

# %%
df1.columns.tolist()
# Out:
# ['Incident ID',
#  'Offence Code',
#  'CR Number',
#  'Dispatch Date / Time',
#  'NIBRS Code',
#  'Victims',
#  'Crime Name1',
#  'Crime Name2',
#  'Crime Name3',
#  'Police District Name',
#  'Block Address',
#  'City',
#  'State',
#  'Zip Code',
#  'Agency',
#  'Place',
#  'Sector',
#  'Beat',
#  'PRA',
#  'Address Number',
#  'Street Prefix',
#  'Street Name',
#  'Street Suffix',
#  'Street Type',
#  'Start_Date_Time',
#  'End_Date_Time',
#  'Latitude',
#  'Longitude',
#  'Police District Number',
#  'Location']

# %%
df1.columns = df1.columns.str.strip().str.replace(' ', '_').str.replace('-', '_')   #Standardize columns

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306094 entries, 0 to 306093
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident_ID             306094 non-null  int64
#  1   Offence_Code            306094 non-null  object
#  2   CR_Number               306094 non-null  int64
#  3   Dispatch_Date_/_Time    257065 non-null  object
#  4   NIBRS_Code              306094 non-null  object
#  5   Victims                 306094 non-null  int64
#  6   Crime_Name1             305822 non-null  object
#  7   Crime_Name2             305822 non-null  object
#  8   Crime_Name3             305822 non-null  object
#  9   Police_District_Name    306000 non-null  object
#  10  Block_Address           279888 non-null  object
#  11  City                    304818 non-null  object
#  12  State                   306094 non-null  object
#  13  Zip_Code                302915 non-null  float64
#  14  Agency                  306094 non-null  object
#  15  Place                   306094 non-null  object
#  16  Sector                  304564 non-null  object
#  17  Beat                    304564 non-null  object
#  18  PRA                     305855 non-null  object
#  19  Address_Number          279985 non-null  float64
#  20  Street_Prefix           13631 non-null   object
#  21  Street_Name             306093 non-null  object
#  22  Street_Suffix           5432 non-null    object
#  23  Street_Type             305755 non-null  object
#  24  Start_Date_Time         306094 non-null  object
#  25  End_Date_Time           144436 non-null  object
#  26  Latitude                306094 non-null  float64
#  27  Longitude               306094 non-null  float64
#  28  Police_District_Number  306094 non-null  object
#  29  Location                306094 non-null  object
# dtypes: float64(4), int64(3), object(23)
# memory usage: 70.1+ MB

# %% [markdown]
# ### Change data types

# %%
# Change Dispatch_Date_time to time series 
df1['Start_Date_Time']=pd.to_datetime(df1['Start_Date_Time'],format='%m/%d/%Y %I:%M:%S %p')
df1['End_Date_Time']=pd.to_datetime(df1['End_Date_Time'],format='%m/%d/%Y %I:%M:%S %p')
df1
# Out:
#         Incident_ID Offence_Code  CR_Number    Dispatch_Date_/_Time  \
# 0         201202980         3550  180042096  08/23/2018 09:52:08 PM
# 1         201181293         3522  180015424  03/30/2018 01:00:55 AM
# 2         201181293         3562  180015424  03/30/2018 01:00:55 AM
# 3         201193163         3520  180029476  06/14/2018 10:26:45 PM
# 4         201204355         2204  180043926  09/03/2018 12:06:54 PM
# ...             ...          ...        ...                     ...
# 306089    201320571         1399  210006666  02/21/2021 07:25:28 AM
# 306090    201329875         2305  210017101  05/06/2021 10:54:47 PM
# 306091    201329751         5016  210016952  05/05/2021 10:38:58 PM
# 306092    201323117         9099  210009468  03/13/2021 12:07:14 PM
# 306093    201327806         2305  210014587  04/19/2021 02:17:29 PM
#
#        NIBRS_Code  Victims             Crime_Name1  \
# 0             35B        1   Crime Against Society
# 1             35A        1   Crime Against Society
# 2             35A        1   Crime Against Society
# 3             35A        1   Crime Against Society
# 4             220        1  Crime Against Property
# ...           ...      ...                     ...
# 306089        13B        1    Crime Against Person
# 306090        23F        1  Crime Against Property
# 306091        90Z        1   Crime Against Society
# 306092        90Z        1   Crime Against Society
# 306093        23F        1  Crime Against Property
#
#                            Crime_Name2  \
# 0            Drug Equipment Violations
# 1             Drug/Narcotic Violations
# 2             Drug/Narcotic Violations
# 3             Drug/Narcotic Violations
# 4       Burglary/Breaking and Entering
# ...                                ...
# 306089                  Simple Assault
# 306090        Theft From Motor Vehicle
# 306091              All Other Offenses
# 306092              All Other Offenses
# 306093        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Street_Prefix     Street_Name Street_Suffix  Street_Type  \
# 0                NaN     MIDDLEBROOK           NaN           RD
# 1                NaN        WOODMONT           NaN          AVE
# 2                NaN        WOODMONT           NaN          AVE
# 3                NaN  QUINCE ORCHARD           NaN           RD
# 4                NaN        FALSTONE           NaN          AVE
# ...              ...             ...           ...          ...
# 306089           NaN       TRANSHIRE           NaN           RD
# 306090           NaN        ATHERTON           NaN           DR
# 306091           NaN       BALTUSROL           NaN           DR
# 306092           NaN          FENTON           NaN           ST
# 306093           NaN    NEWPORT MILL           NaN           RD
#
#            Start_Date_Time       End_Date_Time   Latitude  Longitude  \
# 0      2018-08-23 21:52:00                 NaT  39.177744 -77.265619
# 1      2018-03-30 01:01:00                 NaT  38.992693 -77.097063
# 2      2018-03-30 01:01:00                 NaT  38.992693 -77.097063
# 3      2018-06-14 22:26:00 2018-06-15 03:00:00  39.147954 -77.218189
# 4      2018-09-02 23:30:00 2018-09-03 00:30:00  38.966174 -77.096561
# ...                    ...                 ...        ...        ...
# 306089 2021-02-20 20:00:00                 NaT  39.172701 -77.197340
# 306090 2021-05-06 03:15:00                 NaT  39.059672 -77.075995
# 306091 2021-05-05 22:38:00                 NaT  39.199722 -77.273039
# 306092 2021-03-13 13:35:00                 NaT  38.985813 -77.022915
# 306093 2021-04-18 16:00:00 2021-04-19 12:00:00  39.037115 -77.072485
#
#        Police_District_Number             Location
# 0                          5D  (39.1777, -77.2656)
# 1                          2D  (38.9927, -77.0971)
# 2                          2D  (38.9927, -77.0971)
# 3                          6D   (39.148, -77.2182)
# 4                          2D  (38.9662, -77.0966)
# ...                       ...                  ...
# 306089                     6D  (39.1727, -77.1973)
# 306090                     4D   (39.0597, -77.076)
# 306091                     5D   (39.1997, -77.273)
# 306092                     3D  (38.9858, -77.0229)
# 306093                     2D  (39.0371, -77.0725)
#
# [306094 rows x 30 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306094 entries, 0 to 306093
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident_ID             306094 non-null  int64
#  1   Offence_Code            306094 non-null  object
#  2   CR_Number               306094 non-null  int64
#  3   Dispatch_Date_/_Time    257065 non-null  object
#  4   NIBRS_Code              306094 non-null  object
#  5   Victims                 306094 non-null  int64
#  6   Crime_Name1             305822 non-null  object
#  7   Crime_Name2             305822 non-null  object
#  8   Crime_Name3             305822 non-null  object
#  9   Police_District_Name    306000 non-null  object
#  10  Block_Address           279888 non-null  object
#  11  City                    304818 non-null  object
#  12  State                   306094 non-null  object
#  13  Zip_Code                302915 non-null  float64
#  14  Agency                  306094 non-null  object
#  15  Place                   306094 non-null  object
#  16  Sector                  304564 non-null  object
#  17  Beat                    304564 non-null  object
#  18  PRA                     305855 non-null  object
#  19  Address_Number          279985 non-null  float64
#  20  Street_Prefix           13631 non-null   object
#  21  Street_Name             306093 non-null  object
#  22  Street_Suffix           5432 non-null    object
#  23  Street_Type             305755 non-null  object
#  24  Start_Date_Time         306094 non-null  datetime64[ns]
#  25  End_Date_Time           144436 non-null  datetime64[ns]
#  26  Latitude                306094 non-null  float64
#  27  Longitude               306094 non-null  float64
#  28  Police_District_Number  306094 non-null  object
#  29  Location                306094 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(3), object(21)
# memory usage: 70.1+ MB

# %%
df1['Dispatch_Date_/_Time']=pd.to_datetime(df1['Dispatch_Date_/_Time'], errors='coerce', format='%m/%d/%Y %I:%M:%S %p')

# %% [markdown]
# Columns have some bad date formats

# %%
bad_rows = df1[pd.to_datetime(df1['Dispatch_Date_/_Time'], errors='coerce').isna()] # rows with corrupted formats
bad_rows.head(30)
# Out:
#      Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 6      201121509         5213   17008780                  NaT        520
# 7      201091648         1103   16038843                  NaT        11A
# 8      201108886         1399   16060247                  NaT        13B
# 9      201124327         9199   17012248                  NaT        90Z
# 10     201096093         2399   16044222                  NaT        23H
# 11     201113407         2303   16066213                  NaT        23C
# 15     201114124         1399   16067054                  NaT        13B
# 25     201166702         9105  170547908                  NaT        90Z
# 39     201091655         1103   16038243                  NaT        11A
# 40     201102170         3699   16041077                  NaT        11D
# 45     201122310         2399   17009789                  NaT        23H
# 46     201103518         2804   16053715                  NaT        280
# 47     201103518         3562   16053715                  NaT        35A
# 48     201103518         4802   16053715                  NaT        90Z
# 49     201103518         5202   16053715                  NaT        520
# 62     201257873         2202  190045665                  NaT        220
# 64     201257874         2204  190045666                  NaT        220
# 71     201260639         2204  190049153                  NaT        220
# 73     201260646         2202  190049154                  NaT        220
# 75     201260662         2202  190049164                  NaT        220
# 87     201121240         1103   17008446                  NaT        11A
# 88     201126673         3601   17015167                  NaT        11D
# 94     201223863         2006  190003311                  NaT        200
# 95     201129221         3562   17014987                  NaT        35A
# 96     201129221         5299   17014987                  NaT        520
# 98     201122422         1399   17009733                  NaT        13B
# 100    201103222         2303   16053384                  NaT        23C
# 108    201126029         0912   17014369                  NaT        09A
# 148    201247697         1113  190033117                  NaT        11B
# 167    201112416         2303   16064915                  NaT        23C
#
#      Victims             Crime_Name1                           Crime_Name2  \
# 6          1   Crime Against Society                 Weapon Law Violations
# 7          1    Crime Against Person                         Forcible Rape
# 8          1    Crime Against Person                        Simple Assault
# 9          1                   Other                    All Other Offenses
# 10         1  Crime Against Property                     All other Larceny
# 11         1  Crime Against Property                           Shoplifting
# 15         1    Crime Against Person                        Simple Assault
# 25         1                   Other                    All Other Offenses
# 39         1    Crime Against Person                         Forcible Rape
# 40         1    Crime Against Person                              Fondling
# 45         1  Crime Against Property                     All other Larceny
# 46         1  Crime Against Property              Stolen Property Offenses
# 47         1   Crime Against Society              Drug/Narcotic Violations
# 48         1   Crime Against Society                    All Other Offenses
# 49         1   Crime Against Society                 Weapon Law Violations
# 62         1  Crime Against Property        Burglary/Breaking and Entering
# 64         1  Crime Against Property        Burglary/Breaking and Entering
# 71         1  Crime Against Property        Burglary/Breaking and Entering
# 73         1  Crime Against Property        Burglary/Breaking and Entering
# 75         1  Crime Against Property        Burglary/Breaking and Entering
# 87         1    Crime Against Person                         Forcible Rape
# 88         1    Crime Against Person                     Forcible Fondling
# 94         1  Crime Against Property                                 Arson
# 95         1   Crime Against Society              Drug/Narcotic Violations
# 96         1   Crime Against Society                 Weapon Law Violations
# 98         1    Crime Against Person                        Simple Assault
# 100        1  Crime Against Property                           Shoplifting
# 108        1    Crime Against Person  Murder and Nonnegligent Manslaughter
# 148        1    Crime Against Person                       Forcible Sodomy
# 167        1  Crime Against Property                           Shoplifting
#
#                                     Crime_Name3 Police_District_Name  ...  \
# 6                               WEAPON - FIRING              WHEATON  ...
# 7                             RAPE - STRONG-ARM              WHEATON  ...
# 8                          ASSAULT - 2ND DEGREE        SILVER SPRING  ...
# 9                            POLICE INFORMATION              WHEATON  ...
# 10                   LARCENY (DESCRIBE OFFENSE)              WHEATON  ...
# 11                        LARCENY - SHOPLIFTING   MONTGOMERY VILLAGE  ...
# 15                         ASSAULT - 2ND DEGREE              WHEATON  ...
# 25                                LOST PROPERTY        SILVER SPRING  ...
# 39                            RAPE - STRONG-ARM            ROCKVILLE  ...
# 40                       SEX OFFENSE - FONDLING        SILVER SPRING  ...
# 45                   LARCENY (DESCRIBE OFFENSE)             BETHESDA  ...
# 46                    STOLEN PROPERTY - POSSESS        SILVER SPRING  ...
# 47                  DRUGS - MARIJUANA - POSSESS        SILVER SPRING  ...
# 48   OBSTRUCT POLICE - OBSTRUCT CRIMINAL INVEST        SILVER SPRING  ...
# 49                           WEAPON - CONCEALED        SILVER SPRING  ...
# 62          BURGLARY - FORCED ENTRY-RESIDENTIAL        SILVER SPRING  ...
# 64       BURGLARY - NO FORCED ENTRY-RESIDENTIAL        SILVER SPRING  ...
# 71       BURGLARY - NO FORCED ENTRY-RESIDENTIAL        SILVER SPRING  ...
# 73          BURGLARY - FORCED ENTRY-RESIDENTIAL        SILVER SPRING  ...
# 75          BURGLARY - FORCED ENTRY-RESIDENTIAL        SILVER SPRING  ...
# 87                            RAPE - STRONG-ARM           GERMANTOWN  ...
# 88         SEX OFFENSE - AGAINST CHILD-FONDLING             BETHESDA  ...
# 94                          ARSON - RESIDENTIAL        SILVER SPRING  ...
# 95                  DRUGS - MARIJUANA - POSSESS              WHEATON  ...
# 96            WEAPON OFFENSE (DESCRIBE OFFENSE)              WHEATON  ...
# 98                         ASSAULT - 2ND DEGREE             BETHESDA  ...
# 100                       LARCENY - SHOPLIFTING        SILVER SPRING  ...
# 108                     HOMICIDE - WILLFUL KILL        SILVER SPRING  ...
# 148         SEX ASSAULT - SODOMY-MAN-STRONG-ARM              WHEATON  ...
# 167                       LARCENY - SHOPLIFTING              WHEATON  ...
#
#     Street_Prefix        Street_Name Street_Suffix  Street_Type  \
# 6             NaN              PUNCH           NaN           ST
# 7             NaN            BEL PRE           NaN           RD
# 8             NaN        NORTHAMPTON           NaN           DR
# 9             NaN            GEORGIA           NaN          AVE
# 10            NaN            ROWLAND           NaN           LA
# 11            NaN      WASHINGTONIAN           NaN          BLV
# 15            NaN         WOOLEN OAK           NaN           CT
# 25            NaN    HAMPSHIRE GREEN           NaN           LA
# 39            NaN           ST JAMES           NaN           RD
# 40            NaN          CROSSWOOD           NaN           CT
# 45            NaN             VALLEY           NaN           RD
# 46            NaN           LOCKWOOD           NaN           DR
# 47            NaN           LOCKWOOD           NaN           DR
# 48            NaN           LOCKWOOD           NaN           DR
# 49            NaN           LOCKWOOD           NaN           DR
# 62            NaN  ELLSWORTH HEIGHTS           NaN           ST
# 64            NaN  ELLSWORTH HEIGHTS           NaN           ST
# 71            NaN            CAMERON           NaN           ST
# 73            NaN       CAMERON HILL           NaN           CT
# 75            NaN             RAMSEY           NaN          AVE
# 87            NaN         HONEY HILL           NaN           LA
# 88            NaN           RANDOLPH           NaN           RD
# 94            NaN              ROBEY           NaN          TER
# 95            NaN         STONINGTON           NaN           PL
# 96            NaN         STONINGTON           NaN           PL
# 98            NaN     BRISTOL SQUARE           NaN           LA
# 100           NaN              WAYNE           NaN          AVE
# 108           NaN           MONDRIAN           NaN          TER
# 148           NaN        WESTCHESTER           NaN           DR
# 167           NaN         VEIRS MILL           NaN           RD
#
#         Start_Date_Time       End_Date_Time   Latitude  Longitude  \
# 6   2017-02-18 00:18:00                 NaT  39.088902 -77.042262
# 7   2016-07-31 23:00:00 2016-08-01 05:32:00  39.093783 -77.076369
# 8   2016-11-20 09:00:00                 NaT  39.008359 -76.985601
# 9   2017-03-08 14:03:00                 NaT  39.036218 -77.049887
# 10  2016-08-28 00:00:00 2016-08-29 00:00:00  39.110690 -76.962918
# 11  2016-12-24 15:51:00 2016-12-24 16:37:00  39.114194 -77.197117
# 15  2016-12-17 22:44:00 2016-12-29 00:00:00  39.108360 -77.057510
# 25  2017-12-11 00:00:00                 NaT  39.015143 -76.976145
# 39  2016-07-28 14:00:00                 NaT  39.056273 -77.205623
# 40  2016-08-13 12:21:00                 NaT  39.096173 -76.923480
# 45  2016-12-26 12:00:00 2017-02-23 13:50:00  38.998693 -77.128076
# 46  2016-10-19 01:07:00 2016-10-19 01:07:00  39.041208 -76.986246
# 47  2016-10-19 01:07:00 2016-10-19 01:07:00  39.041208 -76.986246
# 48  2016-10-19 01:07:00 2016-10-19 01:07:00  39.041208 -76.986246
# 49  2016-10-19 01:07:00 2016-10-19 01:07:00  39.041208 -76.986246
# 62  2019-09-24 01:47:00                 NaT  38.999567 -77.022408
# 64  2019-09-24 02:01:00                 NaT  38.999567 -77.022408
# 71  2019-10-13 09:00:00                 NaT  38.996379 -77.031172
# 73  2019-10-12 19:00:00 2019-10-13 09:00:00  38.996115 -77.030409
# 75  2019-10-13 08:19:00                 NaT  38.996103 -77.029869
# 87  2017-02-16 13:46:00                 NaT  39.222834 -77.247883
# 88  2017-03-24 18:30:00 2017-03-24 18:55:00  39.053366 -77.110179
# 94  2019-01-22 19:44:00                 NaT  39.083031 -76.938556
# 95  2017-03-24 01:33:00 2017-03-24 05:30:00  39.047775 -77.019595
# 96  2017-03-24 01:33:00 2017-03-24 05:30:00  39.047775 -77.019595
# 98  2017-02-12 20:00:00 2017-02-12 22:00:00  39.014329 -77.101189
# 100 2016-10-17 17:01:00                 NaT  38.997148 -77.021909
# 108 2017-03-21 02:25:00 2017-03-21 02:25:00  39.072330 -76.991700
# 148 2019-04-06 13:00:00                 NaT  39.040616 -77.043227
# 167 2016-12-18 17:41:00                 NaT  39.037367 -77.051662
#
#     Police_District_Number             Location
# 6                       4D  (39.0889, -77.0423)
# 7                       4D  (39.0938, -77.0764)
# 8                       3D  (39.0084, -76.9856)
# 9                       4D  (39.0362, -77.0499)
# 10                      4D  (39.1107, -76.9629)
# 11                      6D  (39.1142, -77.1971)
# 15                      4D  (39.1084, -77.0575)
# 25                      3D  (39.0151, -76.9761)
# 39                      1D  (39.0563, -77.2056)
# 40                      3D  (39.0962, -76.9235)
# 45                      2D  (38.9987, -77.1281)
# 46                      3D  (39.0412, -76.9862)
# 47                      3D  (39.0412, -76.9862)
# 48                      3D  (39.0412, -76.9862)
# 49                      3D  (39.0412, -76.9862)
# 62                      3D  (38.9996, -77.0224)
# 64                      3D  (38.9996, -77.0224)
# 71                      3D  (38.9964, -77.0312)
# 73                      3D  (38.9961, -77.0304)
# 75                      3D  (38.9961, -77.0299)
# 87                      5D  (39.2228, -77.2479)
# 88                      2D  (39.0534, -77.1102)
# 94                      3D   (39.083, -76.9386)
# 95                      4D  (39.0478, -77.0196)
# 96                      4D  (39.0478, -77.0196)
# 98                      2D  (39.0143, -77.1012)
# 100                     3D  (38.9971, -77.0219)
# 108                     3D  (39.0723, -76.9917)
# 148                     4D  (39.0406, -77.0432)
# 167                     4D  (39.0374, -77.0517)
#
# [30 rows x 30 columns]

# %% [markdown]
# ## Duplicates

# %%
# Utilize the function .duplicated() to check column or dataframe for duplicates
# You can add .any() to scan across a dataframe to locate duplicate values. Returns True or False to that effect
# Use drop_duplicates() to remove ALL duplicates

df1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 306089    False
# 306090    False
# 306091    False
# 306092    False
# 306093    False
# Length: 306094, dtype: bool

# %%
df1.duplicated().any()  # check for duplicates in row or columns
# Out:
# np.False_

# %% [markdown]
# ### Drop duplicates

# %%
# Drop all duplicates
df1=df1.drop_duplicates()
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Street_Prefix     Street_Name Street_Suffix  Street_Type  \
# 0                NaN     MIDDLEBROOK           NaN           RD
# 1                NaN        WOODMONT           NaN          AVE
# 2                NaN        WOODMONT           NaN          AVE
# 3                NaN  QUINCE ORCHARD           NaN           RD
# 4                NaN        FALSTONE           NaN          AVE
# ...              ...             ...           ...          ...
# 306089           NaN       TRANSHIRE           NaN           RD
# 306090           NaN        ATHERTON           NaN           DR
# 306091           NaN       BALTUSROL           NaN           DR
# 306092           NaN          FENTON           NaN           ST
# 306093           NaN    NEWPORT MILL           NaN           RD
#
#            Start_Date_Time       End_Date_Time   Latitude  Longitude  \
# 0      2018-08-23 21:52:00                 NaT  39.177744 -77.265619
# 1      2018-03-30 01:01:00                 NaT  38.992693 -77.097063
# 2      2018-03-30 01:01:00                 NaT  38.992693 -77.097063
# 3      2018-06-14 22:26:00 2018-06-15 03:00:00  39.147954 -77.218189
# 4      2018-09-02 23:30:00 2018-09-03 00:30:00  38.966174 -77.096561
# ...                    ...                 ...        ...        ...
# 306089 2021-02-20 20:00:00                 NaT  39.172701 -77.197340
# 306090 2021-05-06 03:15:00                 NaT  39.059672 -77.075995
# 306091 2021-05-05 22:38:00                 NaT  39.199722 -77.273039
# 306092 2021-03-13 13:35:00                 NaT  38.985813 -77.022915
# 306093 2021-04-18 16:00:00 2021-04-19 12:00:00  39.037115 -77.072485
#
#        Police_District_Number             Location
# 0                          5D  (39.1777, -77.2656)
# 1                          2D  (38.9927, -77.0971)
# 2                          2D  (38.9927, -77.0971)
# 3                          6D   (39.148, -77.2182)
# 4                          2D  (38.9662, -77.0966)
# ...                       ...                  ...
# 306089                     6D  (39.1727, -77.1973)
# 306090                     4D   (39.0597, -77.076)
# 306091                     5D   (39.1997, -77.273)
# 306092                     3D  (38.9858, -77.0229)
# 306093                     2D  (39.0371, -77.0725)
#
# [306094 rows x 30 columns]

# %% [markdown]
# ## Remove unnecessary columns

# %%
df1=df1.drop(['Street_Suffix', 'Street_Prefix', 'End_Date_Time'], axis=1)  #Drop empty and unnecessary columns
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Beat  PRA Address_Number     Street_Name Street_Type  \
# 0       5N1  447        12800.0     MIDDLEBROOK          RD
# 1       2E2  054         8300.0        WOODMONT         AVE
# 2       2E2  054         8300.0        WOODMONT         AVE
# 3       6P2  445          400.0  QUINCE ORCHARD          RD
# 4       2E1  017         4800.0        FALSTONE         AVE
# ...     ...  ...            ...             ...         ...
# 306089  6R2  544        19300.0       TRANSHIRE          RD
# 306090  4K2  333        12500.0        ATHERTON          DR
# 306091  5N1  465          300.0       BALTUSROL          DR
# 306092  3G1  092         7700.0          FENTON          ST
# 306093  2D3  314        11100.0    NEWPORT MILL          RD
#
#            Start_Date_Time   Latitude  Longitude Police_District_Number  \
# 0      2018-08-23 21:52:00  39.177744 -77.265619                     5D
# 1      2018-03-30 01:01:00  38.992693 -77.097063                     2D
# 2      2018-03-30 01:01:00  38.992693 -77.097063                     2D
# 3      2018-06-14 22:26:00  39.147954 -77.218189                     6D
# 4      2018-09-02 23:30:00  38.966174 -77.096561                     2D
# ...                    ...        ...        ...                    ...
# 306089 2021-02-20 20:00:00  39.172701 -77.197340                     6D
# 306090 2021-05-06 03:15:00  39.059672 -77.075995                     4D
# 306091 2021-05-05 22:38:00  39.199722 -77.273039                     5D
# 306092 2021-03-13 13:35:00  38.985813 -77.022915                     3D
# 306093 2021-04-18 16:00:00  39.037115 -77.072485                     2D
#
#                    Location
# 0       (39.1777, -77.2656)
# 1       (38.9927, -77.0971)
# 2       (38.9927, -77.0971)
# 3        (39.148, -77.2182)
# 4       (38.9662, -77.0966)
# ...                     ...
# 306089  (39.1727, -77.1973)
# 306090   (39.0597, -77.076)
# 306091   (39.1997, -77.273)
# 306092  (38.9858, -77.0229)
# 306093  (39.0371, -77.0725)
#
# [306094 rows x 27 columns]

# %%
df1=df1.drop(['Location'], axis=1) # Carries same coordinates as latitude and longitude columns
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Sector Beat  PRA  Address_Number     Street_Name Street_Type  \
# 0           N  5N1  447         12800.0     MIDDLEBROOK          RD
# 1           E  2E2  054          8300.0        WOODMONT         AVE
# 2           E  2E2  054          8300.0        WOODMONT         AVE
# 3           P  6P2  445           400.0  QUINCE ORCHARD          RD
# 4           E  2E1  017          4800.0        FALSTONE         AVE
# ...       ...  ...  ...             ...             ...         ...
# 306089      R  6R2  544         19300.0       TRANSHIRE          RD
# 306090      K  4K2  333         12500.0        ATHERTON          DR
# 306091      N  5N1  465           300.0       BALTUSROL          DR
# 306092      G  3G1  092          7700.0          FENTON          ST
# 306093      D  2D3  314         11100.0    NEWPORT MILL          RD
#
#            Start_Date_Time   Latitude  Longitude  Police_District_Number
# 0      2018-08-23 21:52:00  39.177744 -77.265619                      5D
# 1      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 2      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 3      2018-06-14 22:26:00  39.147954 -77.218189                      6D
# 4      2018-09-02 23:30:00  38.966174 -77.096561                      2D
# ...                    ...        ...        ...                     ...
# 306089 2021-02-20 20:00:00  39.172701 -77.197340                      6D
# 306090 2021-05-06 03:15:00  39.059672 -77.075995                      4D
# 306091 2021-05-05 22:38:00  39.199722 -77.273039                      5D
# 306092 2021-03-13 13:35:00  38.985813 -77.022915                      3D
# 306093 2021-04-18 16:00:00  39.037115 -77.072485                      2D
#
# [306094 rows x 26 columns]

# %% [markdown]
# ## Missing values

# %%
# you need to know where they are and how they affect your dataset
# find them using df.isna(). returns True or False values
df1.isna().sum()
# Out:
# Incident_ID                   0
# Offence_Code                  0
# CR_Number                     0
# Dispatch_Date_/_Time      49029
# NIBRS_Code                    0
# Victims                       0
# Crime_Name1                 272
# Crime_Name2                 272
# Crime_Name3                 272
# Police_District_Name         94
# Block_Address             26206
# City                       1276
# State                         0
# Zip_Code                   3179
# Agency                        0
# Place                         0
# Sector                     1530
# Beat                       1530
# PRA                         239
# Address_Number            26109
# Street_Name                   1
# Street_Type                 339
# Start_Date_Time               0
# Latitude                      0
# Longitude                     0
# Police_District_Number        0
# dtype: int64

# %%
# Remove column if more than 70% of data is missing
df1=df1.dropna(axis=1, thresh=len(df1)*0.7)
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Sector Beat  PRA  Address_Number     Street_Name Street_Type  \
# 0           N  5N1  447         12800.0     MIDDLEBROOK          RD
# 1           E  2E2  054          8300.0        WOODMONT         AVE
# 2           E  2E2  054          8300.0        WOODMONT         AVE
# 3           P  6P2  445           400.0  QUINCE ORCHARD          RD
# 4           E  2E1  017          4800.0        FALSTONE         AVE
# ...       ...  ...  ...             ...             ...         ...
# 306089      R  6R2  544         19300.0       TRANSHIRE          RD
# 306090      K  4K2  333         12500.0        ATHERTON          DR
# 306091      N  5N1  465           300.0       BALTUSROL          DR
# 306092      G  3G1  092          7700.0          FENTON          ST
# 306093      D  2D3  314         11100.0    NEWPORT MILL          RD
#
#            Start_Date_Time   Latitude  Longitude  Police_District_Number
# 0      2018-08-23 21:52:00  39.177744 -77.265619                      5D
# 1      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 2      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 3      2018-06-14 22:26:00  39.147954 -77.218189                      6D
# 4      2018-09-02 23:30:00  38.966174 -77.096561                      2D
# ...                    ...        ...        ...                     ...
# 306089 2021-02-20 20:00:00  39.172701 -77.197340                      6D
# 306090 2021-05-06 03:15:00  39.059672 -77.075995                      4D
# 306091 2021-05-05 22:38:00  39.199722 -77.273039                      5D
# 306092 2021-03-13 13:35:00  38.985813 -77.022915                      3D
# 306093 2021-04-18 16:00:00  39.037115 -77.072485                      2D
#
# [306094 rows x 26 columns]

# %%
# Correct inconsistencies in City names

# %%
df1['City'].nunique()
# Out:
# 66

# %%
df1['City'].unique() # City names wrongly misspelled
# Out:
# array(['GERMANTOWN', 'BETHESDA', 'GAITHERSBURG', 'CHEVY CHASE',
#        'SILVER SPRING', 'ROCKVILLE', 'TAKOMA PARK', 'POTOMAC',
#        'BURTONSVILLE', 'CLARKSBURG', 'OLNEY', 'GLEN ECHO', 'KENSINGTON',
#        'BOYDS', 'ASHTON', 'MONTGOMERY VILLAGE', 'DAMASCUS', 'DERWOOD',
#        'BEALLSVILLE', 'HYATTSVILLE', 'SANDY SPRING', 'DICKERSON', nan,
#        'POOLESVILLE', 'WASHINGTON GROVE', 'BROOKEVILLE', 'CABIN JOHN',
#        'SILVERS SPRING', 'MT AIRY', 'GARRETT PARK', 'SPENCERVILLE',
#        'WASHINGTON', 'ROCKVIILE', 'BARNESVILLE', 'BRINKLOW', 'LAUREL',
#        'GAITHERSBUG', 'MOUNT AIRY', 'BELTSVILLE', 'WHEATON',
#        'FALLS CHURCH', 'FRIENDSHIP HEIGHTS', 'COLLEGE PARK',
#        'NORTH POTOMAC', 'LANHAM', 'CLAEKSBURG', 'NORTH BETHESDA',
#        'HIGHLAND', 'CAPITOL HEIGHTS', 'GAIHTERSBURG', 'RIVERDALE',
#        'MOUNT RAINIER', '0', 'ALEXANDRIA', 'BETHEDA', 'BRENTWOOD',
#        'ADELPHI', 'WOODBINE', 'HAGERSTOWN', 'VIENNA', 'WEST FRIENDSHIP',
#        'MCLEAN', 'TACOMA PARK', 'FREDERICK', 'ROCKVILLLE', 'BOWIE',
#        'GREENBELT'], dtype=object)

# %%
city_update = {
    'SILVERS SPRING': 'SILVER SPRING',
    'ROCKVIILE': 'ROCKVILLE',
    'ROCKVILLLE': 'ROCKVILLE',
    'GAITHERSBUG': 'GAITHERSBURG',
    'GAIHTERSBURG': 'GAITHERSBURG',
    'CLAEKSBURG': 'CLARKSBURG',
    'BETHEDA': 'BETHESDA',
    'TACOMA PARK': 'TAKOMA PARK',
    'MT AIRY': 'MOUNT AIRY'
}

df1['City'] = df1['City'].replace(city_update)

# %%
df1['City'].nunique()  # Check corrected names
# Out:
# 57

# %%
# Replace incorrect state values based on Zipcode matches
state_update= {
    '0': 'invalid state: 0',
    '15': 'invalid state: 15',
    '16': 'invalid state: 16',
    '17': 'invalid state: 17'
}
df1['State']=df1['State'].replace(state_update)
df1['State'].unique()
# Out:
# array(['MD', 'DC', 'invalid state: 16', 'VA', 'ND', 'invalid state: 15',
#        'ME', 'MS', 'invalid state: 0', 'MC', 'invalid state: 17'],
#       dtype=object)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# 1. What is the geographical composition of the county, by police district?
# 2. Which crimes impact victims the most?
# 3. Which offence code records the highest crime entries, and which city are they occurring?
# 4. How has the overall crime frequency evolved between 2018 and 2022, and what seasonal or monthly patterns can be observed during this period?
# 5. How does crime composition differ across agencies and time?

# %% [markdown]
# ## 1. What is the geographical composition of the county and its Police Districts?

# %%
# 1. Define the valid "bounding box" to filter outliers
MIN_LAT = 38.9
MAX_LAT = 39.4
MIN_LON = -77.6
MAX_LON = -76.8

# 2. Filter the DataFrame to get only valid map points
df_map = df1[
    (df1['Latitude'] > MIN_LAT) & (df1['Latitude'] < MAX_LAT) &
    (df1['Longitude'] > MIN_LON) & (df1['Longitude'] < MAX_LON)
]

# 3. Scatter plot
plt.figure(figsize=(10, 10))
sns.scatterplot(
    data=df_map,
    x='Longitude',
    y='Latitude', hue='Police_District_Name',
    s=3,           # 's=none' indicates dot thickness
   
   
)

# 4. Titles and labels
plt.title('Crime Density Map by Police District', fontsize=16)
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)
plt.gca().set_aspect('equal') # squares the map
plt.tight_layout()
plt.show()
print('The concentration of crime within each Police District/City in the county')
# Out:
# /var/folders/30/w31zjr112fz3x672p_ks26z40000gp/T/ipykernel_11948/2741741533.py:29: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# The concentration of crime within each Police District/City in the county

# %% [markdown]
# ## 2. Which crimes impact victims the most?

# %%
# Which crimes impact victims the most?
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Sector Beat  PRA  Address_Number     Street_Name Street_Type  \
# 0           N  5N1  447         12800.0     MIDDLEBROOK          RD
# 1           E  2E2  054          8300.0        WOODMONT         AVE
# 2           E  2E2  054          8300.0        WOODMONT         AVE
# 3           P  6P2  445           400.0  QUINCE ORCHARD          RD
# 4           E  2E1  017          4800.0        FALSTONE         AVE
# ...       ...  ...  ...             ...             ...         ...
# 306089      R  6R2  544         19300.0       TRANSHIRE          RD
# 306090      K  4K2  333         12500.0        ATHERTON          DR
# 306091      N  5N1  465           300.0       BALTUSROL          DR
# 306092      G  3G1  092          7700.0          FENTON          ST
# 306093      D  2D3  314         11100.0    NEWPORT MILL          RD
#
#            Start_Date_Time   Latitude  Longitude  Police_District_Number
# 0      2018-08-23 21:52:00  39.177744 -77.265619                      5D
# 1      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 2      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 3      2018-06-14 22:26:00  39.147954 -77.218189                      6D
# 4      2018-09-02 23:30:00  38.966174 -77.096561                      2D
# ...                    ...        ...        ...                     ...
# 306089 2021-02-20 20:00:00  39.172701 -77.197340                      6D
# 306090 2021-05-06 03:15:00  39.059672 -77.075995                      4D
# 306091 2021-05-05 22:38:00  39.199722 -77.273039                      5D
# 306092 2021-03-13 13:35:00  38.985813 -77.022915                      3D
# 306093 2021-04-18 16:00:00  39.037115 -77.072485                      2D
#
# [306094 rows x 26 columns]

# %%
df1['Victims'].value_counts()
# Out:
# Victims
# 1     300473
# 2       4762
# 3        576
# 4        188
# 5         57
# 6         17
# 7         14
# 8          4
# 12         2
# 22         1
# Name: count, dtype: int64

# %%
df1['Victims'].describe()
# Out:
# count    306094.000000
# mean          1.022692
# std           0.192311
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          22.000000
# Name: Victims, dtype: float64

# %%
# Crimes victims are impacted by the most
df1.groupby('Crime_Name1')['Victims'].value_counts()
# Out:
# Crime_Name1             Victims
# Crime Against Person    1           25132
#                         2            4378
#                         3             524
#                         4             165
#                         5              45
#                         7              12
#                         6              11
#                         8               2
#                         22              1
# Crime Against Property  1          139882
# Crime Against Society   1           68917
# Not a Crime             1            3573
#                         2               2
# Other                   1           62703
#                         2             377
#                         3              52
#                         4              23
#                         5              11
#                         6               6
#                         7               2
#                         8               2
#                         12              2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 6))
crime_victim_sum = df1.groupby('Crime_Name1')['Victims'].sum().sort_values(ascending=False)

sns.barplot(                     
    x=crime_victim_sum.index,
    y=crime_victim_sum.values
)                                # Bar chart

plt.xticks(rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Total Number of Victims")
plt.title("Total Victim Count per Crime Type")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

sns.boxplot(
    y='Crime_Name1',
    x='Victims',
    data=df1,
    palette='Blues',
    hue='Crime_Name1',
    legend=False
)

plt.xlabel("Number of Victims")
plt.ylabel("Crime Type")
plt.title("Distribution of Victims Across Crime Types")
plt.tight_layout()
plt.show()

# %%
# Distribution of victims of crimes across Police Districts

plt.figure(figsize=(14, 6))
sns.boxplot(x='Victims', y='Police_District_Name', data=df1, palette='coolwarm', hue='Police_District_Name', legend=False)
plt.xlabel('Victims')
plt.ylabel('Police District')
plt.title('Distribution of victims of crimes across Police Districts')
# Out:
# Text(0.5, 1.0, 'Distribution of victims of crimes across Police Districts')

# %% [markdown]
# Seems to be an outlier of 22 victims impacted at a go by a crime at Silver Spring

# %% [markdown]
# ## 3. Which offence code records the highest crime entries, and which city are they occurring?

# %%
df1['Offence_Code'].count()
# Out:
# np.int64(306094)

# %%
df1['Offence_Code'].value_counts()  # Counts of offence codes
# Out:
# Offence_Code
# 2305    26275
# 9199    18489
# 1399    17441
# 2303    16076
# 3562    15613
#         ...
# 4101        1
# 2802        1
# 4999        1
# 1002        1
# 5199        1
# Name: count, Length: 342, dtype: int64

# %%
df1['Offence_Code'].describe()
# Out:
# count     306094
# unique       342
# top         2305
# freq       26275
# Name: Offence_Code, dtype: object

# %% [markdown]
# The offence code recorded the most is 2305.

# %%
off_code=df1.groupby('Offence_Code')['Crime_Name1'].value_counts().sort_values(ascending=False).head(5) # Top 3 crimes by Offence Code
off_code
# Out:
# Offence_Code  Crime_Name1
# 2305          Crime Against Property    26275
# 9199          Other                     18489
# 1399          Crime Against Person      17441
# 2303          Crime Against Property    16076
# 3562          Crime Against Society     15613
# Name: count, dtype: int64

# %% [markdown]
# Victims suffer from crimes against property the most

# %%
off_code_df=off_code.reset_index()
off_code_df.columns=['Offence_Code', 'Crime_Name1', 'Count']      # Change series to dataframe

# Bar Chart
plt.figure(figsize=(14,5))
sns.barplot(data=off_code_df, 
            x='Crime_Name1', 
            y='Count', 
            hue='Offence_Code',
           dodge=True)

plt.title('Top 5 crimes by Offence Code')
plt.xlabel('Crime')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
off_code_df
# Out:
#   Offence_Code             Crime_Name1  Count
# 0         2305  Crime Against Property  26275
# 1         9199                   Other  18489
# 2         1399    Crime Against Person  17441
# 3         2303  Crime Against Property  16076
# 4         3562   Crime Against Society  15613

# %%
# Concentration of crime 

# 1. Define the valid "bounding box" to filter outliers
MIN_LAT = 38.9
MAX_LAT = 39.4
MIN_LON = -77.6
MAX_LON = -76.8

# 2. Filter the DataFrame to get only valid map points
df_map = df1[
    (df1['Latitude'] > MIN_LAT) & (df1['Latitude'] < MAX_LAT) &
    (df1['Longitude'] > MIN_LON) & (df1['Longitude'] < MAX_LON)
]

df_off_code = df_map.merge(
    off_code_df[['Offence_Code', 'Crime_Name1']],
    on=['Offence_Code', 'Crime_Name1'],
    how='inner'
)

# Clean city names
df_off_code['Police_District_Name'] = df_off_code['Police_District_Name'].str.strip().str.title()

# Pivot table
heatmap_data = df_off_code.pivot_table(
    index='Police_District_Name',
    columns='Crime_Name1',
    aggfunc='size',
    fill_value=0
)

# Select only the top 5 crimes (1D list)
top5_crimes = df_off_code['Crime_Name1'].unique().tolist()
heatmap_data = heatmap_data[top5_crimes]  # safe, 1D selection

# Optional: sort cities alphabetically
heatmap_data = heatmap_data.sort_index()

# Draw heatmap
plt.figure(figsize=(14, max(5, len(heatmap_data)*0.5)))

sns.heatmap(
    heatmap_data,
    cmap='Reds',
    linewidths=.5,
    annot=True,
    fmt='d'
)

plt.title('Impact of Top 5 High-Frequency Crimes Across Police Districts', fontsize=16)
plt.xlabel('Crime Type', fontsize=12, labelpad=10)
plt.ylabel('City', fontsize=12, labelpad=10)
plt.tight_layout()
plt.show()

# %%
# Concentration of crime 

# 1. Define the valid "bounding box" to filter outliers
MIN_LAT = 38.9
MAX_LAT = 39.4
MIN_LON = -77.6
MAX_LON = -76.8

# 2. Filter the DataFrame to get only valid map points
df_map = df1[
    (df1['Latitude'] > MIN_LAT) & (df1['Latitude'] < MAX_LAT) &
    (df1['Longitude'] > MIN_LON) & (df1['Longitude'] < MAX_LON)
]

df_off_code = df_map.merge(
    off_code_df[['Offence_Code', 'Crime_Name1']],
    on=['Offence_Code', 'Crime_Name1'],
    how='inner'
)

# Clean city names
df_off_code['City'] = df_off_code['City'].str.strip().str.title()

# Pivot table
heatmap_data = df_off_code.pivot_table(
    index='City',
    columns='Crime_Name1',
    aggfunc='size',
    fill_value=0
)

# Select only the top 5 crimes (1D list)
top5_crimes = df_off_code['Crime_Name1'].unique().tolist()
heatmap_data = heatmap_data[top5_crimes]  # safe, 1D selection

# Optional: sort cities alphabetically
heatmap_data = heatmap_data.sort_index()

# Draw heatmap
plt.figure(figsize=(14, max(5, len(heatmap_data)*0.5)))

sns.heatmap(
    heatmap_data,
    cmap='Reds',
    linewidths=.5,
    annot=True,
    fmt='d'
)

plt.title('Impact of Top 5 High-Frequency Crimes Across Cities', fontsize=16)
plt.xlabel('Crime Type', fontsize=12, labelpad=10)
plt.ylabel('City', fontsize=12, labelpad=10)
plt.tight_layout()
plt.show()

# %%
off_code2=df1.groupby('Crime_Name2')['Place'].value_counts().sort_values(ascending=False).head(5) # Top 5 crimes by Offence Code
off_code2
# Out:
# Crime_Name2                  Place
# All Other Offenses           Residence - Single Family      14638
# Drug/Narcotic Violations     Street - In vehicle            12880
# Driving Under the Influence  Street - In vehicle            11854
# All Other Offenses           Residence - Apartment/Condo    10991
#                              Other/Unknown                   8175
# Name: count, dtype: int64

# %%
off_code_df2=off_code2.reset_index()
off_code_df2.columns=['Offence_Code', 'Crime_Name2', 'Count']      # Change series to dataframe

# Bar Chart
plt.figure(figsize=(14,5))
sns.barplot(data=off_code_df2, 
            x='Crime_Name2', 
            y='Count', 
            hue='Offence_Code',
           dodge=True)

plt.title('Top 5 crimes by Offence Code')
plt.xlabel('Crime')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## 4. How has the overall crime frequency evolved between 2016 and 2022, and what seasonal or monthly patterns can be observed during this period?

# %%
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#        Sector Beat  PRA  Address_Number     Street_Name Street_Type  \
# 0           N  5N1  447         12800.0     MIDDLEBROOK          RD
# 1           E  2E2  054          8300.0        WOODMONT         AVE
# 2           E  2E2  054          8300.0        WOODMONT         AVE
# 3           P  6P2  445           400.0  QUINCE ORCHARD          RD
# 4           E  2E1  017          4800.0        FALSTONE         AVE
# ...       ...  ...  ...             ...             ...         ...
# 306089      R  6R2  544         19300.0       TRANSHIRE          RD
# 306090      K  4K2  333         12500.0        ATHERTON          DR
# 306091      N  5N1  465           300.0       BALTUSROL          DR
# 306092      G  3G1  092          7700.0          FENTON          ST
# 306093      D  2D3  314         11100.0    NEWPORT MILL          RD
#
#            Start_Date_Time   Latitude  Longitude  Police_District_Number
# 0      2018-08-23 21:52:00  39.177744 -77.265619                      5D
# 1      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 2      2018-03-30 01:01:00  38.992693 -77.097063                      2D
# 3      2018-06-14 22:26:00  39.147954 -77.218189                      6D
# 4      2018-09-02 23:30:00  38.966174 -77.096561                      2D
# ...                    ...        ...        ...                     ...
# 306089 2021-02-20 20:00:00  39.172701 -77.197340                      6D
# 306090 2021-05-06 03:15:00  39.059672 -77.075995                      4D
# 306091 2021-05-05 22:38:00  39.199722 -77.273039                      5D
# 306092 2021-03-13 13:35:00  38.985813 -77.022915                      3D
# 306093 2021-04-18 16:00:00  39.037115 -77.072485                      2D
#
# [306094 rows x 26 columns]

# %%
# Determine trends across the year
df1['Year']=df1['Start_Date_Time'].dt.year  # Add a year column to the dataframe based on start date time entries

# %%
crime_trend=df1.groupby('Year')['Crime_Name1'].value_counts()   # Identifying crime count per year
crime_trend
# Out:
# Year  Crime_Name1
# 2016  Crime Against Property    12435
#       Crime Against Society      7812
#       Other                      5156
#       Crime Against Person       2498
#       Not a Crime                 340
# 2017  Crime Against Property    24267
#       Crime Against Society     15860
#       Other                     10501
#       Crime Against Person       4964
#       Not a Crime                 683
# 2018  Crime Against Property    21650
#       Crime Against Society     15839
#       Other                     11081
#       Crime Against Person       5130
#       Not a Crime                 625
# 2019  Crime Against Property    22026
#       Crime Against Society     13048
#       Other                     10762
#       Crime Against Person       4946
#       Not a Crime                 639
# 2020  Crime Against Property    22945
#       Other                      9805
#       Crime Against Society      7127
#       Crime Against Person       4423
#       Not a Crime                 514
# 2021  Crime Against Property    23086
#       Other                      9567
#       Crime Against Society      5446
#       Crime Against Person       5069
#       Not a Crime                 395
# 2022  Crime Against Property    13473
#       Other                      6306
#       Crime Against Society      3785
#       Crime Against Person       3240
#       Not a Crime                 379
# Name: count, dtype: int64

# %%
crime_trend_df=crime_trend.reset_index()     # Convert previous to dataframe
crime_trend_df.columns=['Year', 'Crime_Name1', 'Count']
crime_trend_df
# Out:
#     Year             Crime_Name1  Count
# 0   2016  Crime Against Property  12435
# 1   2016   Crime Against Society   7812
# 2   2016                   Other   5156
# 3   2016    Crime Against Person   2498
# 4   2016             Not a Crime    340
# 5   2017  Crime Against Property  24267
# 6   2017   Crime Against Society  15860
# 7   2017                   Other  10501
# 8   2017    Crime Against Person   4964
# 9   2017             Not a Crime    683
# 10  2018  Crime Against Property  21650
# 11  2018   Crime Against Society  15839
# 12  2018                   Other  11081
# 13  2018    Crime Against Person   5130
# 14  2018             Not a Crime    625
# 15  2019  Crime Against Property  22026
# 16  2019   Crime Against Society  13048
# 17  2019                   Other  10762
# 18  2019    Crime Against Person   4946
# 19  2019             Not a Crime    639
# 20  2020  Crime Against Property  22945
# 21  2020                   Other   9805
# 22  2020   Crime Against Society   7127
# 23  2020    Crime Against Person   4423
# 24  2020             Not a Crime    514
# 25  2021  Crime Against Property  23086
# 26  2021                   Other   9567
# 27  2021   Crime Against Society   5446
# 28  2021    Crime Against Person   5069
# 29  2021             Not a Crime    395
# 30  2022  Crime Against Property  13473
# 31  2022                   Other   6306
# 32  2022   Crime Against Society   3785
# 33  2022    Crime Against Person   3240
# 34  2022             Not a Crime    379

# %%
plt.figure(figsize=(10,8))       # Draw a line plot
sns.lineplot(data=crime_trend_df,
             x='Year',
             y='Count',
             hue='Crime_Name1',
            marker='o')
plt.grid(                        # plot grid lines to enhance visualisation
    True,            
    which='both',    
    linestyle='--',  
    linewidth=0.5,   
    alpha=0.7)

plt.xlabel('Year')
plt.ylabel('Crime Count')
plt.title('Crime Trends across 7 years')
# Out:
# Text(0.5, 1.0, 'Crime Trends across 7 years')

# %%
# Determine crime trend across months
df1['Month']=df1['Start_Date_Time'].dt.month                           # Create a month column based on start date time entries
month_count = df1['Month'].value_counts().sort_index().reset_index()   # Align months in chronological order and determine count
month_count.columns = ['Month', 'Count']                              # Rename the columns for a clean plot

months = {                                                          # Create dictionary to define month names
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
}
month_count['Month Name'] = month_count['Month'].map(months)      # We create a new column 'Month Name' by applying this map

plt.figure(figsize=(10,5))                                             # Draw line plot to illustrate
sns.lineplot(month_count,
            x='Month Name',
            y='Count',
            marker='o')
plt.grid(                        # Grid lines to enhance visualisation
    True,            
    which='both',    
    linestyle='--',  
    linewidth=0.5,   
    alpha=0.7)

plt.xlabel('Month')
plt.ylabel('Crime Count')
plt.title('Crime Trend per Month')
# Out:
# Text(0.5, 1.0, 'Crime Trend per Month')

# %% [markdown]
# ## 5. How do major crime categories vary across cities and agencies over time, and which combinations show the strongest crime trends or anomalies?

# %%
df1
# Out:
#         Incident_ID Offence_Code  CR_Number Dispatch_Date_/_Time NIBRS_Code  \
# 0         201202980         3550  180042096  2018-08-23 21:52:08        35B
# 1         201181293         3522  180015424  2018-03-30 01:00:55        35A
# 2         201181293         3562  180015424  2018-03-30 01:00:55        35A
# 3         201193163         3520  180029476  2018-06-14 22:26:45        35A
# 4         201204355         2204  180043926  2018-09-03 12:06:54        220
# ...             ...          ...        ...                  ...        ...
# 306089    201320571         1399  210006666  2021-02-21 07:25:28        13B
# 306090    201329875         2305  210017101  2021-05-06 22:54:47        23F
# 306091    201329751         5016  210016952  2021-05-05 22:38:58        90Z
# 306092    201323117         9099  210009468  2021-03-13 12:07:14        90Z
# 306093    201327806         2305  210014587  2021-04-19 14:17:29        23F
#
#         Victims             Crime_Name1                     Crime_Name2  \
# 0             1   Crime Against Society       Drug Equipment Violations
# 1             1   Crime Against Society        Drug/Narcotic Violations
# 2             1   Crime Against Society        Drug/Narcotic Violations
# 3             1   Crime Against Society        Drug/Narcotic Violations
# 4             1  Crime Against Property  Burglary/Breaking and Entering
# ...         ...                     ...                             ...
# 306089        1    Crime Against Person                  Simple Assault
# 306090        1  Crime Against Property        Theft From Motor Vehicle
# 306091        1   Crime Against Society              All Other Offenses
# 306092        1   Crime Against Society              All Other Offenses
# 306093        1  Crime Against Property        Theft From Motor Vehicle
#
#                                        Crime_Name3 Police_District_Name  ...  \
# 0                 DRUGS - NARCOTIC EQUIP - POSSESS           GERMANTOWN  ...
# 1            DRUGS - OPIUM OR DERIVATIVE - POSSESS             BETHESDA  ...
# 2                      DRUGS - MARIJUANA - POSSESS             BETHESDA  ...
# 3               DRUGS - OPIUM OR DERIVATIVE - SELL   MONTGOMERY VILLAGE  ...
# 4           BURGLARY - NO FORCED ENTRY-RESIDENTIAL             BETHESDA  ...
# ...                                            ...                  ...  ...
# 306089                        ASSAULT - 2ND DEGREE   MONTGOMERY VILLAGE  ...
# 306090                         LARCENY - FROM AUTO              WHEATON  ...
# 306091  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 306092                          ALL OTHER OFFENSES        SILVER SPRING  ...
# 306093                         LARCENY - FROM AUTO             BETHESDA  ...
#
#         PRA Address_Number     Street_Name  Street_Type     Start_Date_Time  \
# 0       447        12800.0     MIDDLEBROOK           RD 2018-08-23 21:52:00
# 1       054         8300.0        WOODMONT          AVE 2018-03-30 01:01:00
# 2       054         8300.0        WOODMONT          AVE 2018-03-30 01:01:00
# 3       445          400.0  QUINCE ORCHARD           RD 2018-06-14 22:26:00
# 4       017         4800.0        FALSTONE          AVE 2018-09-02 23:30:00
# ...     ...            ...             ...          ...                 ...
# 306089  544        19300.0       TRANSHIRE           RD 2021-02-20 20:00:00
# 306090  333        12500.0        ATHERTON           DR 2021-05-06 03:15:00
# 306091  465          300.0       BALTUSROL           DR 2021-05-05 22:38:00
# 306092  092         7700.0          FENTON           ST 2021-03-13 13:35:00
# 306093  314        11100.0    NEWPORT MILL           RD 2021-04-18 16:00:00
#
#          Latitude  Longitude Police_District_Number  Year  Month
# 0       39.177744 -77.265619                     5D  2018      8
# 1       38.992693 -77.097063                     2D  2018      3
# 2       38.992693 -77.097063                     2D  2018      3
# 3       39.147954 -77.218189                     6D  2018      6
# 4       38.966174 -77.096561                     2D  2018      9
# ...           ...        ...                    ...   ...    ...
# 306089  39.172701 -77.197340                     6D  2021      2
# 306090  39.059672 -77.075995                     4D  2021      5
# 306091  39.199722 -77.273039                     5D  2021      5
# 306092  38.985813 -77.022915                     3D  2021      3
# 306093  39.037115 -77.072485                     2D  2021      4
#
# [306094 rows x 28 columns]

# %%
# Identify how crime types vary across cities
city_crime=df1.groupby('City')['Crime_Name3'].value_counts().sort_values(ascending=False)
city_crime
# Out:
# City              Crime_Name3
# SILVER SPRING     LARCENY - FROM AUTO                                  8688
#                   DRUGS - MARIJUANA - POSSESS                          7235
#                   ASSAULT - 2ND DEGREE                                 5981
#                   LARCENY - SHOPLIFTING                                5577
#                   DRIVING UNDER THE INFLUENCE LIQUOR                   5313
#                                                                        ...
# WHEATON           AUTO THEFT - VEHICLE THEFT                              1
# WEST FRIENDSHIP   LOST PROPERTY                                           1
# WASHINGTON GROVE  UNAUTHORIZED USE OF VEHICLE (INCLUDES JOY RIDING)       1
#                   LARCENY - FROM AUTO                                     1
# BOYDS             WEAPON - THREAT TO BURN                                 1
# Name: count, Length: 3967, dtype: int64

# %%
city_crime_df=city_crime.reset_index()   # Change analysis above to dataframe 
city_crime_df.columns=['City', 'Crime_Name3', 'Count']
city_crime_df
# Out:
#                   City                                        Crime_Name3  \
# 0        SILVER SPRING                                LARCENY - FROM AUTO
# 1        SILVER SPRING                        DRUGS - MARIJUANA - POSSESS
# 2        SILVER SPRING                               ASSAULT - 2ND DEGREE
# 3        SILVER SPRING                              LARCENY - SHOPLIFTING
# 4        SILVER SPRING                 DRIVING UNDER THE INFLUENCE LIQUOR
# ...                ...                                                ...
# 3962           WHEATON                         AUTO THEFT - VEHICLE THEFT
# 3963   WEST FRIENDSHIP                                      LOST PROPERTY
# 3964  WASHINGTON GROVE  UNAUTHORIZED USE OF VEHICLE (INCLUDES JOY RIDING)
# 3965  WASHINGTON GROVE                                LARCENY - FROM AUTO
# 3966             BOYDS                            WEAPON - THREAT TO BURN
#
#       Count
# 0      8688
# 1      7235
# 2      5981
# 3      5577
# 4      5313
# ...     ...
# 3962      1
# 3963      1
# 3964      1
# 3965      1
# 3966      1
#
# [3967 rows x 3 columns]

# %%
# Identify the top 10 cities
top_10_cities=df1['City'].value_counts().head(10).index
top_10_cities
# Out:
# Index(['SILVER SPRING', 'GAITHERSBURG', 'ROCKVILLE', 'GERMANTOWN', 'BETHESDA',
#        'MONTGOMERY VILLAGE', 'TAKOMA PARK', 'CHEVY CHASE', 'POTOMAC',
#        'DERWOOD'],
#       dtype='object', name='City')

# %%
filtered_df = city_crime_df[city_crime_df['City'].isin(top_10_cities)]   # filter grouped data and plot

plt.figure(figsize=(10,5))
sns.barplot(
    data=filtered_df,
    x='City',
    y='Count',
    legend=False
)
plt.xticks(rotation=45)
plt.title("Crime Types Across Top Cities")
plt.show()

# %%
df1.groupby('Place')['Crime_Name3'].value_counts().sort_values(ascending=False)
# Out:
# Place                 Crime_Name3
# Street - In vehicle   DRIVING UNDER THE INFLUENCE LIQUOR          11309
#                       DRUGS - MARIJUANA - POSSESS                  9573
# Residence - Driveway  LARCENY - FROM AUTO                          7334
# Other/Unknown         IDENTITY THEFT                               5704
# Street - Residential  LARCENY - FROM AUTO                          5667
#                                                                   ...
# Wooded Area           SEX OFFENSE - INDECENT EXPOSURE TO ADULT        1
#                       SEX OFFENSE - INDECENT EXPOSURE                 1
#                       SEX ASSAULT - SODOMY-WOMAN-STRONG-ARM           1
#                       SEX ASSAULT - SODOMY-MAN-GUN                    1
#                       SEX ASSAULT - CARNAL ABUSE                      1
# Name: count, Length: 7597, dtype: int64

# %%
df1['City'].value_counts()
# Out:
# City
# SILVER SPRING         105488
# GAITHERSBURG           44600
# ROCKVILLE              42495
# GERMANTOWN             30066
# BETHESDA               21242
# MONTGOMERY VILLAGE      9445
# TAKOMA PARK             8370
# CHEVY CHASE             6410
# POTOMAC                 6336
# DERWOOD                 5496
# KENSINGTON              4824
# OLNEY                   4679
# BURTONSVILLE            3776
# CLARKSBURG              3248
# DAMASCUS                2552
# BOYDS                   1968
# BROOKEVILLE              919
# POOLESVILLE              897
# ASHTON                   419
# SANDY SPRING             392
# DICKERSON                292
# CABIN JOHN               227
# SPENCERVILLE             149
# MOUNT AIRY                92
# GLEN ECHO                 91
# BRINKLOW                  72
# LAUREL                    49
# BARNESVILLE               48
# BEALLSVILLE               43
# WASHINGTON                23
# BELTSVILLE                19
# GARRETT PARK              16
# HYATTSVILLE               16
# WASHINGTON GROVE           9
# HIGHLAND                   9
# WOODBINE                   7
# WHEATON                    6
# LANHAM                     5
# ADELPHI                    4
# COLLEGE PARK               2
# FRIENDSHIP HEIGHTS         1
# NORTH BETHESDA             1
# NORTH POTOMAC              1
# FALLS CHURCH               1
# RIVERDALE                  1
# MOUNT RAINIER              1
# 0                          1
# ALEXANDRIA                 1
# CAPITOL HEIGHTS            1
# BRENTWOOD                  1
# HAGERSTOWN                 1
# VIENNA                     1
# WEST FRIENDSHIP            1
# MCLEAN                     1
# FREDERICK                  1
# BOWIE                      1
# GREENBELT                  1
# Name: count, dtype: int64
